# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from pprint import pprint
import pickle
import time
import datetime

# %%
# Import qubit states Zero (|0>) and One (|1>), and Pauli operators (X, Y, Z)
from qiskit.circuit import QuantumCircuit, QuantumRegister, Parameter
# from qiskit.tools.monitor import job_monitor
from qiskit.compiler import transpile
from qiskit.transpiler.passes import RemoveBarriers

# %%
# Import state tomography modules
from qiskit_experiments.library import StateTomography
from kagome_trotter.patch_ignis import rename_qcs_StateTomography_to_ignis
from kagome_trotter.tomography import StateTomographyFitter
from qiskit.quantum_info import state_fidelity

# %%
from kagome_trotter.circuits_initial import gate_initial_state
from kagome_trotter.circuits_1d_path import gate_path_proposed, gate_path_conventional
from kagome_trotter.simulator_dm import make_dm_binary, hamiltonian_to_dm, DMExtended
from kagome_trotter.hamiltonian import Hamiltonian, make_H_Heisenberg_path
from kagome_trotter.backend_simulator import result_to_dms
from setting import *
# Out:
# NoiseModel:
#   Basis gates: ['cx', 'cz', 'h', 'id', 'rx', 'rz', 's', 'sdg', 'sx', 'u1', 'u2', 'u3', 'x']
#   Instructions with noise: ['sx', 'cx', 'h', 'rz', 'u1', 'cz', 'rx', 'u2', 'u3', 'sdg', 's', 'x']
#   All-qubits errors: ['rx', 'rz', 'sx', 'h', 'sdg', 's', 'x', 'u1', 'u2', 'u3', 'cx', 'cz']

# %%
dt = Parameter(r"$\Delta t$")
state_initial_dm = DMExtended(matrix=make_dm_binary(str_binary=state_initial,
                                                    endian_binary="big",
                                                    endian_dm="little")) ### make the density matrix for the initial state

H_Heisenberg = make_H_Heisenberg_path(num_qubits=num_qubits) ### create Heisenberg Hamiltonian in a dictionary format
matrix_Heisenberg = hamiltonian_to_dm(hamiltonian=H_Heisenberg) ### convert Heisenberg Hamiltonian to its matrix form

U_Heisenberg = DMExtended(sp.linalg.expm(-1.0j * matrix_Heisenberg * time_evolution)) ### prepare the unitary matrix of the Heisenberg Hamiltonian

state_target_dm = state_initial_dm.apply_unitary(U_Heisenberg) ### apply the unitary evolution to the density matrix
state_target_dm.is_valid()
# Out:
# True

# %%
fidelities = []
nums_cnots = []

print("trotter step list: ", num_steps_list)
for num_steps in num_steps_list:
    
    print("trotter steps: ", num_steps)
    t1 = time.perf_counter()
    
    # Initialize quantum circuit for 3 qubits
    qc = QuantumCircuit(num_qubits)

    # Prepare initial state
    qc.compose(gate_initial_state(state_initial=state_initial),
               qubits=list(range(num_qubits)),
               inplace=True,)
    
    qc.append(instruction=gate_path_proposed(num_qubits=num_qubits,
                                             num_steps=num_steps // 2, ###!
                                             dt=dt * 2, ###!
                                             to_instruction=True,
                                             add_barrier=False,
                                          ),
              qargs=list(range(num_qubits)),
             )

    # Evaluate simulation at target_time (t=pi) meaning each trotter step evolves pi/trotter_steps in time
    qc = qc.assign_parameters({dt: time_evolution / num_steps})
    qc_t3 = transpile(RemoveBarriers()(qc), optimization_level=3, basis_gates=["sx", "cx", "rz"])
    qc_t3.save_density_matrix()
    
    ### execute circuits
    result_raw = simulator_ideal.run(qc_t3,
                                     shots=0,
                                    ).result()
    dm_raw = result_to_dms(result=result_raw,
                           endian_result="little",
                           endian_dm="little",
                          )[0]

    fidelities.append(state_fidelity(dm_raw, state_target_dm))
    nums_cnots.append(qc_t3.count_ops().get("cx"))
    
    t2 = time.perf_counter()
    print("raw state tomography fidelity = {:.4f}".format(fidelities[-1]))
    print("number of CNOT gates:", qc_t3.count_ops().get("cx"))
    print("time:", t2 - t1)
    print()
# Out:
# trotter step list:  [4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64, 68, 72, 76, 80, 84, 88, 92, 96]
# trotter steps:  4
# raw state tomography fidelity = 0.3478
# number of CNOT gates: 4
# time: 0.026868917047977448
#
# trotter steps:  8
# raw state tomography fidelity = 0.2236
# number of CNOT gates: 64
# time: 0.018119291169568896
#
# trotter steps:  12
# raw state tomography fidelity = 0.1876
# number of CNOT gates: 96
# time: 0.02348945802077651
#
# trotter steps:  16
# raw state tomography fidelity = 0.6392
# number of CNOT gates: 128
# time: 0.030508332885801792
#
# trotter steps:  20
# raw state tomography fidelity = 0.8319
# number of CNOT gates: 160
# time: 0.10304662492126226
#
# trotter steps:  24
# raw state tomography fidelity = 0.9111
# number of CNOT gates: 192
# time: 0.04471675003878772
#
# trotter steps:  28
# raw state tomography fidelity = 0.9476
# number of CNOT gates: 224
# time: 0.04794745799154043
#
# trotter steps:  32
# raw state tomography fidelity = 0.9663
# number of CNOT gates: 256
# time: 0.05235604220069945
#
# trotter steps:  36
# raw state tomography fidelity = 0.9768
# number of CNOT gates: 288
# time: 0.05699220788665116
#
# trotter steps:  40
# raw state tomography fidelity = 0.9832
# number of CNOT gates: 320
# time: 0.06387170916423202
#
# trotter steps:  44
# raw state tomography fidelity = 0.9873
# number of CNOT gates: 352
# time: 0.06920483405701816
#
# trotter steps:  48
# raw state tomography fidelity = 0.9901
# number of CNOT gates: 384
# time: 0.16125299991108477
#
# trotter steps:  52
# raw state tomography fidelity = 0.9921
# number of CNOT gates: 416
# time: 0.08863558294251561
#
# trotter steps:  56
# raw state tomography fidelity = 0.9935
# number of CNOT gates: 448
# time: 0.09017466683872044
#
# trotter steps:  60
# raw state tomography fidelity = 0.9946
# number of CNOT gates: 480
# time: 0.09606862487271428
#
# trotter steps:  64
# raw state tomography fidelity = 0.9954
# number of CNOT gates: 512
# time: 0.09956504194997251
#
# trotter steps:  68
# raw state tomography fidelity = 0.9961
# number of CNOT gates: 544
# time: 0.20850966591387987
#
# trotter steps:  72
# raw state tomography fidelity = 0.9966
# number of CNOT gates: 576
# time: 0.11951712495647371
#
# trotter steps:  76
# raw state tomography fidelity = 0.9970
# number of CNOT gates: 608
# time: 0.12170791695825756
#
# trotter steps:  80
# raw state tomography fidelity = 0.9974
# number of CNOT gates: 640
# time: 0.13005975005216897
#
# trotter steps:  84
# raw state tomography fidelity = 0.9976
# number of CNOT gates: 672
# time: 0.25375712499953806
#
# trotter steps:  88
# raw state tomography fidelity = 0.9979
# number of CNOT gates: 704
# time: 0.14186833309940994
#
# trotter steps:  92
# raw state tomography fidelity = 0.9981
# number of CNOT gates: 736
# time: 0.14770970796234906
#
# trotter steps:  96
# raw state tomography fidelity = 0.9983
# number of CNOT gates: 768
# time: 0.15135970781557262

# %%
plt.plot(num_steps_list, fidelities)
plt.xlabel("Trotter steps")
plt.ylabel("state fidelity")
plt.show()

# %%
with open("run_proposed.pkl", "wb") as f:
    pickle.dump(obj={"num_steps_list": num_steps_list, 
                     "fidelities": fidelities, 
                     "nums_cnots": nums_cnots},
                file=f)

# %%
qc = QuantumCircuit(num_qubits)
qc.compose(gate_initial_state(state_initial=state_initial,
                              to_instruction=False,
                              add_barrier=True,),
            qubits=list(range(num_qubits)),
            inplace=True,)

qc.compose(gate_path_proposed(num_qubits=num_qubits,
                                            num_steps=1, ###!
                                            dt=dt,
                                            to_instruction=False,
                                            add_barrier=True,
                                        ),
            qubits=list(range(num_qubits)),
            inplace=True,
            )
qc.draw("mpl")

# %%
qc = QuantumCircuit(num_qubits)

# Prepare initial state
qc.compose(gate_initial_state(state_initial=state_initial),
            qubits=list(range(num_qubits)),
            inplace=True,)

qc.append(instruction=gate_path_proposed(num_qubits=num_qubits,
                                            num_steps=2, ###!
                                            dt=dt,
                                            to_instruction=False,
                                            add_barrier=False,
                                        ),
            qargs=list(range(num_qubits)),
            )

# Evaluate simulation at target_time (t=pi) meaning each trotter step evolves pi/trotter_steps in time
qc = qc.assign_parameters({dt: time_evolution / num_steps})
# qc_t3 = transpile(RemoveBarriers()(qc), optimization_level=3, basis_gates=["sx", "cx", "rz"])
qc_t3 = transpile(qc, optimization_level=0, basis_gates=["sx", "cx", "rz"])
qc_t3.save_density_matrix()
qc_t3.draw("mpl")

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from pprint import pprint
import pickle
import time
import datetime

# %%
# Import qubit states Zero (|0>) and One (|1>), and Pauli operators (X, Y, Z)
from qiskit.circuit import QuantumCircuit, QuantumRegister, Parameter
# from qiskit.tools.monitor import job_monitor
from qiskit.compiler import transpile
from qiskit.transpiler.passes import RemoveBarriers

# %%
# Import state tomography modules
from qiskit_experiments.library import StateTomography
from kagome_trotter.patch_ignis import rename_qcs_StateTomography_to_ignis
from kagome_trotter.tomography import StateTomographyFitter
from qiskit.quantum_info import state_fidelity

# %%
from kagome_trotter.circuits_initial import gate_initial_state
from kagome_trotter.circuits_path import gate_path_hybrid
from kagome_trotter.simulator_dm import make_dm_binary, hamiltonian_to_dm, DMExtended
from kagome_trotter.hamiltonian import Hamiltonian, make_H_Heisenberg_path
from kagome_trotter.backend_simulator import result_to_dms
from setting import *
# Out:
# NoiseModel:
#   Basis gates: ['cx', 'cz', 'h', 'id', 'rx', 'rz', 's', 'sdg', 'sx', 'u1', 'u2', 'u3', 'x']
#   Instructions with noise: ['u2', 'rx', 'rz', 'x', 'cx', 'u3', 'sdg', 'h', 's', 'cz', 'sx', 'u1']
#   All-qubits errors: ['rx', 'rz', 'sx', 'h', 'sdg', 's', 'x', 'u1', 'u2', 'u3', 'cx', 'cz']

# %%
dt = Parameter(r"$\Delta t$")
state_initial_dm = DMExtended(matrix=make_dm_binary(str_binary=state_initial,
                                                    endian_binary="big",
                                                    endian_dm="little")) ### make the density matrix for the initial state

H_Heisenberg = make_H_Heisenberg_path(num_qubits=num_qubits) ### create Heisenberg Hamiltonian in a dictionary format
matrix_Heisenberg = hamiltonian_to_dm(hamiltonian=H_Heisenberg) ### convert Heisenberg Hamiltonian to its matrix form

U_Heisenberg = DMExtended(sp.linalg.expm(-1.0j * matrix_Heisenberg * time_evolution)) ### prepare the unitary matrix of the Heisenberg Hamiltonian

state_target_dm = state_initial_dm.apply_unitary(U_Heisenberg) ### apply the unitary evolution to the density matrix
state_target_dm.is_valid()
# Out:
# True

# %%
fidelities = []
nums_cnots = []

print("trotter step list: ", num_steps_list)
for num_steps in num_steps_list:
    
    print("trotter steps: ", num_steps)
    t1 = time.perf_counter()
    
    # Initialize quantum circuit for 3 qubits
    qc = QuantumCircuit(num_qubits)

    # Prepare initial state
    qc.compose(gate_initial_state(state_initial=state_initial),
               qubits=list(range(num_qubits)),
               inplace=True,)
    
    qc.append(instruction=gate_path_hybrid(num_qubits=num_qubits,
                                             num_steps=num_steps // 2, ###!
                                             dt=dt * 2, ###!
                                             type_H_eff=type_H_eff,
                                             to_instruction=True,
                                             add_barrier=False,
                                          ),
              qargs=list(range(num_qubits)),
             )

    # Evaluate simulation at target_time (t=pi) meaning each trotter step evolves pi/trotter_steps in time
    qc = qc.assign_parameters({dt: time_evolution / num_steps})
    qc_t3 = transpile(RemoveBarriers()(qc), optimization_level=3, basis_gates=["sx", "cx", "rz"])
    qc_t3.save_density_matrix()
    
    ### execute circuits
    result_raw = simulator_ideal.run(qc_t3,
                                     shots=0,
                                    ).result()
    dm_raw = result_to_dms(result=result_raw,
                           endian_result="little",
                           endian_dm="little",
                          )[0]

    fidelities.append(state_fidelity(dm_raw, state_target_dm))
    nums_cnots.append(qc_t3.count_ops().get("cx"))
    
    t2 = time.perf_counter()
    print("raw state tomography fidelity = {:.4f}".format(fidelities[-1]))
    print("number of CNOT gates:", qc_t3.count_ops().get("cx"))
    print("time:", t2 - t1)
    print()
# Out:
# trotter step list:  [4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64, 68, 72, 76, 80, 84, 88, 92, 96]
# trotter steps:  4
# raw state tomography fidelity = 0.3478
# number of CNOT gates: None
# time: 0.022556417156010866
#
# trotter steps:  8
# raw state tomography fidelity = 0.2643
# number of CNOT gates: 56
# time: 0.013336292002350092
#
# trotter steps:  12
# raw state tomography fidelity = 0.0610
# number of CNOT gates: 84
# time: 0.021063792053610086
#
# trotter steps:  16
# raw state tomography fidelity = 0.4362
# number of CNOT gates: 112
# time: 0.022429666947573423
#
# trotter steps:  20
# raw state tomography fidelity = 0.6672
# number of CNOT gates: 140
# time: 0.02669012499973178
#
# trotter steps:  24
# raw state tomography fidelity = 0.7914
# number of CNOT gates: 168
# time: 0.03030074993148446
#
# trotter steps:  28
# raw state tomography fidelity = 0.8598
# number of CNOT gates: 196
# time: 0.09679187508299947
#
# trotter steps:  32
# raw state tomography fidelity = 0.9000
# number of CNOT gates: 224
# time: 0.042283917078748345
#
# trotter steps:  36
# raw state tomography fidelity = 0.9253
# number of CNOT gates: 252
# time: 0.04268574994057417
#
# trotter steps:  40
# raw state tomography fidelity = 0.9421
# number of CNOT gates: 280
# time: 0.048603500006720424
#
# trotter steps:  44
# raw state tomography fidelity = 0.9537
# number of CNOT gates: 308
# time: 0.05164708290249109
#
# trotter steps:  48
# raw state tomography fidelity = 0.9622
# number of CNOT gates: 336
# time: 0.05822420911863446
#
# trotter steps:  52
# raw state tomography fidelity = 0.9685
# number of CNOT gates: 364
# time: 0.0582763331476599
#
# trotter steps:  56
# raw state tomography fidelity = 0.9733
# number of CNOT gates: 392
# time: 0.06458395812660456
#
# trotter steps:  60
# raw state tomography fidelity = 0.9771
# number of CNOT gates: 420
# time: 0.06997883296571672
#
# trotter steps:  64
# raw state tomography fidelity = 0.9801
# number of CNOT gates: 448
# time: 0.07541504106484354
#
# trotter steps:  68
# raw state tomography fidelity = 0.9826
# number of CNOT gates: 476
# time: 0.16002799989655614
#
# trotter steps:  72
# raw state tomography fidelity = 0.9846
# number of CNOT gates: 504
# time: 0.08983524981886148
#
# trotter steps:  76
# raw state tomography fidelity = 0.9863
# number of CNOT gates: 532
# time: 0.0906977909617126
#
# trotter steps:  80
# raw state tomography fidelity = 0.9877
# number of CNOT gates: 560
# time: 0.09324024990200996
#
# trotter steps:  84
# raw state tomography fidelity = 0.9889
# number of CNOT gates: 588
# time: 0.09796574991196394
#
# trotter steps:  88
# raw state tomography fidelity = 0.9900
# number of CNOT gates: 616
# time: 0.09653800004161894
#
# trotter steps:  92
# raw state tomography fidelity = 0.9908
# number of CNOT gates: 644
# time: 0.10523008299060166
#
# trotter steps:  96
# raw state tomography fidelity = 0.9916
# number of CNOT gates: 672
# time: 0.21410429198294878

# %%
plt.plot(num_steps_list, fidelities)
plt.xlabel("Trotter steps")
plt.ylabel("state fidelity")
plt.show()

# %%
with open("run_hybrid.pkl", "wb") as f:
    pickle.dump(obj={"num_steps_list": num_steps_list, 
                     "fidelities": fidelities, 
                     "nums_cnots": nums_cnots},
                file=f)

# %%
qc = QuantumCircuit(num_qubits)
qc.compose(gate_initial_state(state_initial=state_initial,
                              to_instruction=False,
                              add_barrier=True,),
            qubits=list(range(num_qubits)),
            inplace=True,)

qc.compose(gate_path_hybrid(num_qubits=num_qubits,
                            num_steps=1, ###!
                            dt=dt,
                            type_H_eff=type_H_eff,
                            to_instruction=False,
                            add_barrier=True,
                        ),
            qubits=list(range(num_qubits)),
            inplace=True,
            )
qc.draw("mpl")

# %%
qc = QuantumCircuit(num_qubits)

# Prepare initial state
qc.compose(gate_initial_state(state_initial=state_initial),
            qubits=list(range(num_qubits)),
            inplace=True,)

qc.append(instruction=gate_path_hybrid(num_qubits=num_qubits,
                                            num_steps=2, ###!
                                            dt=dt,
                                            type_H_eff=type_H_eff,
                                            to_instruction=False,
                                            add_barrier=False,
                                        ),
            qargs=list(range(num_qubits)),
            )

# Evaluate simulation at target_time (t=pi) meaning each trotter step evolves pi/trotter_steps in time
qc = qc.assign_parameters({dt: time_evolution / num_steps})
# qc_t3 = transpile(RemoveBarriers()(qc), optimization_level=3, basis_gates=["sx", "cx", "rz"])
qc_t3 = transpile(qc, optimization_level=0, basis_gates=["sx", "cx", "rz"])
qc_t3.save_density_matrix()
qc_t3.draw("mpl")

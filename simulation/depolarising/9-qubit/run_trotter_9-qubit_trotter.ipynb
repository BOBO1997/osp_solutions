# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from pprint import pprint
import pickle
import time
import datetime

# %%
# Import qubit states Zero (|0>) and One (|1>), and Pauli operators (X, Y, Z)
from qiskit.circuit import QuantumCircuit, QuantumRegister, Parameter
# from qiskit.tools.monitor import job_monitor
from qiskit.compiler import transpile
from qiskit.transpiler.passes import RemoveBarriers

# %%
# Import state tomography modules
from qiskit_experiments.library import StateTomography
from osp_solutions.patch_ignis import rename_qcs_StateTomography_to_ignis
from osp_solutions.tomography import StateTomographyFitter
from qiskit.quantum_info import state_fidelity

# %%
from osp_solutions.circuits import append_block_trotter, append_block_trotter_proposed, append_initial_state, append_block_trotter_aj, append_block_trotter_negishi
from osp_solutions.simulator_dm import make_dm_binary, hamiltonian_to_dm, DMExtended
from osp_solutions.hamiltonian import Hamiltonian, make_H_Heisenberg
from osp_solutions.backend_simulator import result_to_dms
from setting import *

# %%
from qiskit_aer import AerSimulator
from qiskit_aer.noise import NoiseModel, pauli_error
# from qiskit_ibm_runtime.fake_provider import FakeJakartaV2
# backend = AerSimulator.from_backend(FakeJakartaV2())
# backend = Aer.get_backend("qasm_simulator")
###? p_dep1 = 1.0 * 1e-4
error_dep1 = pauli_error([("I", 1 - 3 * p_dep1 / 4), ("X", p_dep1 / 4), ("Y", p_dep1 / 4), ("Z", p_dep1 / 4)])
# error_dep2_local = error_dep1.tensor(error_dep1)

###? p_dep2 = 1.0 * 1e-3
error_dep2_global = pauli_error([("II", 1 - 15 * p_dep2 / 16), ("IX", p_dep2 / 16), ("IY", p_dep2 / 16), ("IZ", p_dep2 / 16),
                                 ("XI", p_dep2 / 16), ("XX", p_dep2 / 16), ("XY", p_dep2 / 16), ("XZ", p_dep2 / 16),
                                 ("YI", p_dep2 / 16), ("YX", p_dep2 / 16), ("YY", p_dep2 / 16), ("YZ", p_dep2 / 16),
                                 ("ZI", p_dep2 / 16), ("ZX", p_dep2 / 16), ("ZY", p_dep2 / 16), ("ZZ", p_dep2 / 16)])

# print(error_dep2_global)

# Add errors to noise model
noise_model = NoiseModel()
noise_model.add_all_qubit_quantum_error(error_dep1, ["rx", "rz", "sx", "h", "sdg", "s", "x", "u1", "u2", "u3"])
noise_model.add_all_qubit_quantum_error(error_dep2_global, ["cz"])
# noise_model.add_all_qubit_quantum_error(error_3, ["cswap", "ccx"])
print(noise_model)
print()

# Create noisy simulator backend
simulator_noisy = AerSimulator(method="density_matrix",
                               noise_model=noise_model)
simulator_ideal = AerSimulator(method="density_matrix")
# Out:
# NoiseModel:
#   Basis gates: ['cx', 'cz', 'h', 'id', 'rx', 'rz', 's', 'sdg', 'sx', 'u1', 'u2', 'u3', 'x']
#   Instructions with noise: ['cz', 'h', 's', 'u1', 'u3', 'rz', 'sx', 'u2', 'x', 'sdg', 'rx']
#   All-qubits errors: ['rx', 'rz', 'sx', 'h', 'sdg', 's', 'x', 'u1', 'u2', 'u3', 'cz']

# %%
###? num_qubits = 5

# The final time of the state evolution
###? time_evolution = np.pi

# Parameterize variable t to be evaluated at t=pi later
dt = Parameter('t')

# initial layout
# initial_layout = [5,3,1]
###? initial_layout = list(range(num_qubits))

# Number of trotter steps
# num_steps_list = [4,10,50,100,200] # ,20,30,40,50] # ,60,70,80,90,100]
###? num_steps_list = list(range(4,100,4))
print("trotter step list: ", num_steps_list)

###? state_initial_str = "10101" ### specify initial state
state_initial_dm = DMExtended(matrix=make_dm_binary(str_binary=state_initial_str, 
                                                    endian_binary="little_endian", 
                                                    endian_dm="big_endian")) ### make the density matrix for the initial state

H_Heisenberg = make_H_Heisenberg(num_qubits=num_qubits) ### create Heisenberg Hamiltonian in a dictionary format
matrix_Heisenberg = hamiltonian_to_dm(hamiltonian=H_Heisenberg) ### convert Heisenberg Hamiltonian to its matrix form

U_Heisenberg = DMExtended(sp.linalg.expm(-1.0j * matrix_Heisenberg * time_evolution)) ### prepare the unitary matrix of the Heisenberg Hamiltonian

state_target_dm = state_initial_dm.apply_unitary(U_Heisenberg) ### apply the unitary evolution to the density matrix
state_target_dm.is_valid()
# Out:
# trotter step list:  [4, 16, 28, 40, 52, 64, 76, 88, 100, 112, 124, 136, 148, 160, 172, 184, 196, 208, 220, 232, 244, 256, 268, 280, 292]
# True

# %%
fidelities = []
nums_cnots = []

for num_steps in num_steps_list:
    
    print("trotter steps: ", num_steps)
    t1 = time.perf_counter()
    
    # Initialize quantum circuit for 3 qubits
    qr = QuantumRegister(num_qubits, 
                         name="q")
    qc = QuantumCircuit(qr)

    # Prepare initial state
    append_initial_state(qc=qc, 
                         state_initial_str=state_initial_str)
    append_block_trotter_negishi(qc=qc, 
                            dt=dt, 
                            option="a",
                            num_steps=num_steps)

    # Evaluate simulation at target_time (t=pi) meaning each trotter step evolves pi/trotter_steps in time
    qc = qc.assign_parameters({dt: time_evolution / num_steps})
    qc_t3 = transpile(RemoveBarriers()(qc), optimization_level=3, basis_gates=["sx", "cx", "rz"])
    qc_t3.save_density_matrix()
    
    ### execute circuits
    result_raw = simulator_noisy.run(qc_t3,
                                        shots=0,
                                        ).result()
    dm_raw = result_to_dms(result=result_raw,
                        endian_dm="big")[0]

    fidelities.append(state_fidelity(dm_raw, state_target_dm))
    nums_cnots.append(qc_t3.count_ops().get("cx"))
    
    t2 = time.perf_counter()
    print('raw state tomography fidelity = {:.4f} \u00B1 {:.4f}'.format(np.mean(fidelities), np.std(fidelities)))
    print("number of CNOT gates:", qc_t3.count_ops().get("cx"))
    print("time:", t2 - t1)
    print()
# Out:
# trotter steps:  4
# raw state tomography fidelity = 0.0061 ± 0.0000
# number of CNOT gates: 96
# time: 0.6108842079993337
#
# trotter steps:  16
# raw state tomography fidelity = 0.3658 ± 0.3597
# number of CNOT gates: 384
# time: 0.8620380409993231
#
# trotter steps:  28
# raw state tomography fidelity = 0.5177 ± 0.3639
# number of CNOT gates: 672
# time: 1.2057640829589218
#
# trotter steps:  40
# raw state tomography fidelity = 0.5874 ± 0.3374
# number of CNOT gates: 960
# time: 1.5633239580783993
#
# trotter steps:  52
# raw state tomography fidelity = 0.6211 ± 0.3093
# number of CNOT gates: 1248
# time: 1.573737540980801
#
# trotter steps:  64
# raw state tomography fidelity = 0.6367 ± 0.2845
# number of CNOT gates: 1536
# time: 1.9165861670626327
#
# trotter steps:  76
# raw state tomography fidelity = 0.6420 ± 0.2637
# number of CNOT gates: 1824
# time: 2.3236795420525596
#
# trotter steps:  88
# raw state tomography fidelity = 0.6410 ± 0.2467
# number of CNOT gates: 2112
# time: 2.9157674580346793
#
# trotter steps:  100
# raw state tomography fidelity = 0.6362 ± 0.2330
# number of CNOT gates: 2400
# time: 2.9575649170437828
#
# trotter steps:  112
# raw state tomography fidelity = 0.6288 ± 0.2221
# number of CNOT gates: 2688
# time: 3.2677023339783773
#
# trotter steps:  124
# raw state tomography fidelity = 0.6198 ± 0.2137
# number of CNOT gates: 2976
# time: 3.4352568748872727
#
# trotter steps:  136
# raw state tomography fidelity = 0.6097 ± 0.2073
# number of CNOT gates: 3264
# time: 3.709153375006281
#
# trotter steps:  148
# raw state tomography fidelity = 0.5989 ± 0.2027
# number of CNOT gates: 3552
# time: 4.090406375005841
#
# trotter steps:  160
# raw state tomography fidelity = 0.5876 ± 0.1995
# number of CNOT gates: 3840
# time: 4.219739665975794
#
# trotter steps:  172
# raw state tomography fidelity = 0.5761 ± 0.1975
# number of CNOT gates: 4128
# time: 4.650162042002194
#
# trotter steps:  184
# raw state tomography fidelity = 0.5646 ± 0.1964
# number of CNOT gates: 4416
# time: 4.955202957964502
#
# trotter steps:  196
# raw state tomography fidelity = 0.5530 ± 0.1960
# number of CNOT gates: 4704
# time: 5.641075541032478
#
# trotter steps:  208
# raw state tomography fidelity = 0.5415 ± 0.1963
# number of CNOT gates: 4992
# time: 5.999274916015565
#
# trotter steps:  220
# raw state tomography fidelity = 0.5302 ± 0.1970
# number of CNOT gates: 5280
# time: 6.070742917014286
#
# trotter steps:  232
# raw state tomography fidelity = 0.5190 ± 0.1981
# number of CNOT gates: 5568
# time: 6.204352083033882
#
# trotter steps:  244
# raw state tomography fidelity = 0.5081 ± 0.1994
# number of CNOT gates: 5856
# time: 6.104350375011563
#
# trotter steps:  256
# raw state tomography fidelity = 0.4974 ± 0.2009
# number of CNOT gates: 6144
# time: 4.83529370801989
#
# trotter steps:  268
# raw state tomography fidelity = 0.4869 ± 0.2026
# number of CNOT gates: 6432
# time: 5.019481583032757
#
# trotter steps:  280
# raw state tomography fidelity = 0.4767 ± 0.2043
# number of CNOT gates: 6720
# time: 5.319136457983404
#
# trotter steps:  292
# raw state tomography fidelity = 0.4667 ± 0.2060
# number of CNOT gates: 7008
# time: 5.568071709014475

# %%
with open("run_trotter_"+str(num_qubits)+"-qubit_trotter.pkl", "wb") as f:
    pickle.dump({"num_steps_list": num_steps_list, "fidelities": fidelities, "nums_cnots": nums_cnots}, f)

# %%
plt.plot(num_steps_list, fidelities)
plt.xlabel("Trotter steps")
plt.ylabel("state fidelity")
plt.show()

# %%
qc = QuantumCircuit(num_qubits)

# Prepare initial state
append_initial_state(qc=qc, 
                        state_initial_str=state_initial_str)
append_block_trotter_negishi(qc=qc, 
                              dt=dt,
                              option="a",
                              num_steps=2)

# Evaluate simulation at target_time (t=pi) meaning each trotter step evolves pi/trotter_steps in time
qc = qc.assign_parameters({dt: time_evolution / num_steps})
# qc_t3 = transpile(RemoveBarriers()(qc), optimization_level=3, basis_gates=["sx", "cx", "rz"])
qc_t3 = transpile(qc, optimization_level=0, basis_gates=["sx", "cx", "rz"])
qc_t3.save_density_matrix()
qc_t3.draw("mpl")

# %%
# t3_st_qcs[0].draw("mpl")

# %%
print(simulator_noisy)
# Out:
# AerSimulator('aer_simulator_density_matrix'
#              noise_model=<NoiseModel on ['cz', 'h', 's', 'u1', 'u3', 'rz', 'sx', 'u2', 'x', 'sdg', 'rx']>)

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from pprint import pprint
import pickle
import time
import datetime

# %%
# Import qubit states Zero (|0>) and One (|1>), and Pauli operators (X, Y, Z)
from qiskit.circuit import QuantumCircuit, QuantumRegister, Parameter
# from qiskit.tools.monitor import job_monitor
from qiskit.compiler import transpile
from qiskit.transpiler.passes import RemoveBarriers

# %%
# Import state tomography modules
from qiskit_experiments.library import StateTomography
from osp_solutions.patch_ignis import rename_qcs_StateTomography_to_ignis
from osp_solutions.tomography import StateTomographyFitter
from qiskit.quantum_info import state_fidelity

# %%
from osp_solutions.circuits import gate_path_proposed, gate_initial_state, gate_path_conventional
from osp_solutions.simulator_dm import make_dm_binary, hamiltonian_to_dm, DMExtended
from osp_solutions.hamiltonian import Hamiltonian, make_H_Heisenberg_path
from osp_solutions.backend_simulator import result_to_dms
from setting import *
# Out:
# NoiseModel:
#   Basis gates: ['cx', 'cz', 'h', 'id', 'rx', 'rz', 's', 'sdg', 'sx', 'u1', 'u2', 'u3', 'x']
#   Instructions with noise: ['u2', 's', 'sx', 'sdg', 'rx', 'rz', 'u1', 'cx', 'cz', 'u3', 'x', 'h']
#   All-qubits errors: ['rx', 'rz', 'sx', 'h', 'sdg', 's', 'x', 'u1', 'u2', 'u3', 'cx', 'cz']

# %%
dt = Parameter('t')
state_initial_dm = DMExtended(matrix=make_dm_binary(str_binary=state_initial,
                                                    endian_binary="big",
                                                    endian_dm="little")) ### make the density matrix for the initial state

H_Heisenberg = make_H_Heisenberg_path(num_qubits=num_qubits) ### create Heisenberg Hamiltonian in a dictionary format
matrix_Heisenberg = hamiltonian_to_dm(hamiltonian=H_Heisenberg) ### convert Heisenberg Hamiltonian to its matrix form

U_Heisenberg = DMExtended(sp.linalg.expm(-1.0j * matrix_Heisenberg * time_evolution)) ### prepare the unitary matrix of the Heisenberg Hamiltonian

state_target_dm = state_initial_dm.apply_unitary(U_Heisenberg) ### apply the unitary evolution to the density matrix
state_target_dm.is_valid()
# Out:
# True

# %%
fidelities = []
nums_cnots = []

print("trotter step list: ", num_steps_list)
for num_steps in num_steps_list:
    
    print("trotter steps: ", num_steps)
    t1 = time.perf_counter()
    
    # Initialize quantum circuit for 3 qubits
    qc = QuantumCircuit(num_qubits)

    # Prepare initial state
    qc.compose(gate_initial_state(state_initial=state_initial),
               qubits=list(range(num_qubits)),
               inplace=True,)
    
    qc.append(instruction=gate_path_conventional(num_qubits=num_qubits,
                                           num_steps=num_steps,
                                           dt=dt,
                                           to_instruction=False,
                                           add_barrier=False,
                                          ),
              qargs=list(range(num_qubits)),
             )

    # Evaluate simulation at target_time (t=pi) meaning each trotter step evolves pi/trotter_steps in time
    qc = qc.assign_parameters({dt: time_evolution / num_steps})
    qc_t3 = transpile(RemoveBarriers()(qc), optimization_level=3, basis_gates=["sx", "cx", "rz"])
    qc_t3.save_density_matrix()
    
    ### execute circuits
    result_raw = simulator_ideal.run(qc_t3,
                                     shots=0,
                                    ).result()
    dm_raw = result_to_dms(result=result_raw,
                           endian_result="little",
                           endian_dm="little",
                          )[0]

    fidelities.append(state_fidelity(dm_raw, state_target_dm))
    nums_cnots.append(qc_t3.count_ops().get("cx"))
    
    t2 = time.perf_counter()
    print('raw state tomography fidelity = {:.4f} \u00B1 {:.4f}'.format(np.mean(fidelities), np.std(fidelities)))
    print("number of CNOT gates:", qc_t3.count_ops().get("cx"))
    print("time:", t2 - t1)
    print()
# Out:
# trotter step list:  [4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64, 68, 72, 76, 80, 84, 88, 92, 96]
# trotter steps:  4
# raw state tomography fidelity = 0.0006 ± 0.0000
# number of CNOT gates: 192
# time: 0.04170583304949105
#
# trotter steps:  8
# raw state tomography fidelity = 0.3114 ± 0.3108
# number of CNOT gates: 768
# time: 0.16603820910677314
#
# trotter steps:  12
# raw state tomography fidelity = 0.2250 ± 0.2817
# number of CNOT gates: 1728
# time: 0.23196941590867937
#
# trotter steps:  16
# raw state tomography fidelity = 0.3330 ± 0.3074
# number of CNOT gates: 3072
# time: 0.5365392919629812
#
# trotter steps:  20
# raw state tomography fidelity = 0.3499 ± 0.2770
# number of CNOT gates: 4800
# time: 0.8605814159382135
#
# trotter steps:  24
# raw state tomography fidelity = 0.4328 ± 0.3135
# number of CNOT gates: 6912
# time: 1.2861237498000264
#
# trotter steps:  28
# raw state tomography fidelity = 0.4578 ± 0.2966
# number of CNOT gates: 9408
# time: 1.6556579999160022
#
# trotter steps:  32
# raw state tomography fidelity = 0.5068 ± 0.3063
# number of CNOT gates: 12288
# time: 2.3936382080428302
#
# trotter steps:  36
# raw state tomography fidelity = 0.5020 ± 0.2891
# number of CNOT gates: 15552
# time: 3.0620473749004304
#
# trotter steps:  40
# raw state tomography fidelity = 0.5356 ± 0.2922
# number of CNOT gates: 19200
# time: 3.732218916993588
#
# trotter steps:  44
# raw state tomography fidelity = 0.5408 ± 0.2791
# number of CNOT gates: 23232
# time: 4.480686833150685
#
# trotter steps:  48
# raw state tomography fidelity = 0.5710 ± 0.2854
# number of CNOT gates: 27648
# time: 5.326102540828288
#
# trotter steps:  52
# raw state tomography fidelity = 0.5653 ± 0.2749
# number of CNOT gates: 32448
# time: 6.450944375013933
#
# trotter steps:  56
# raw state tomography fidelity = 0.5657 ± 0.2649
# number of CNOT gates: 37632
# time: 7.4479852500371635
#
# trotter steps:  60
# raw state tomography fidelity = 0.5519 ± 0.2611
# number of CNOT gates: 43200
# time: 8.727593916002661
#
# trotter steps:  64
# raw state tomography fidelity = 0.5437 ± 0.2548
# number of CNOT gates: 49152
# time: 10.34913512505591
#
# trotter steps:  68
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 20
#      15 # Prepare initial state
#      16 qc.compose(gate_initial_state(state_initial=state_initial),
#      17            qubits=list(range(num_qubits)),
#      18            inplace=True,)
# ---> 20 qc.append(instruction=gate_path_conventional(num_qubits=num_qubits,
#      21                                        num_steps=num_steps,
#      22                                        dt=dt,
#      23                                        to_instruction=False,
#      24                                        add_barrier=False,
#      25                                       ),
#      26           qargs=list(range(num_qubits)),
#      27          )
#      29 # Evaluate simulation at target_time (t=pi) meaning each trotter step evolves pi/trotter_steps in time
#      30 qc = qc.assign_parameters({dt: time_evolution / num_steps})
#
# File ~/Documents/projects/osp_solutions/.venv/lib/python3.11/site-packages/qiskit/circuit/quantumcircuit.py:2831, in QuantumCircuit.append(self, instruction, qargs, cargs, copy)
#    2829             param = _validate_expr(circuit_scope, param)
#    2830     if copy and is_parameter:
# -> 2831         operation = _copy.deepcopy(operation)
#    2832 if isinstance(operation, ControlFlowOp):
#    2833     if operation.name == "box" and operation.unit == "expr":
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/copy.py:153, in deepcopy(x, memo, _nil)
#     151 copier = getattr(x, "__deepcopy__", None)
#     152 if copier is not None:
# --> 153     y = copier(memo)
#     154 else:
#     155     reductor = dispatch_table.get(cls)
#
# File ~/Documents/projects/osp_solutions/.venv/lib/python3.11/site-packages/qiskit/circuit/instruction.py:451, in Instruction.__deepcopy__(self, memo)
#     449 cpy._params = copy.copy(self._params)
#     450 if self._definition:
# --> 451     cpy._definition = copy.deepcopy(self._definition, memo)
#     452 return cpy
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/copy.py:153, in deepcopy(x, memo, _nil)
#     151 copier = getattr(x, "__deepcopy__", None)
#     152 if copier is not None:
# --> 153     y = copier(memo)
#     154 else:
#     155     reductor = dispatch_table.get(cls)
#
# File ~/Documents/projects/osp_solutions/.venv/lib/python3.11/site-packages/qiskit/circuit/quantumcircuit.py:1593, in QuantumCircuit.__deepcopy__(self, memo)
#    1589 result._builder_api = _OuterCircuitScopeInterface(result)
#    1591 # Avoids pulling self._data into a Python list
#    1592 # like we would when pickling.
# -> 1593 result._data = self._data.copy(deepcopy=True)
#    1594 result._data.replace_bits(
#    1595     qubits=_copy.deepcopy(self._data.qubits, memo),
#    1596     clbits=_copy.deepcopy(self._data.clbits, memo),
#    1597     qregs=_copy.deepcopy(self._data.qregs, memo),
#    1598     cregs=_copy.deepcopy(self._data.cregs, memo),
#    1599 )
#    1600 return result
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/copy.py:153, in deepcopy(x, memo, _nil)
#     151 copier = getattr(x, "__deepcopy__", None)
#     152 if copier is not None:
# --> 153     y = copier(memo)
#     154 else:
#     155     reductor = dispatch_table.get(cls)
#
# File ~/Documents/projects/osp_solutions/.venv/lib/python3.11/site-packages/qiskit/circuit/instruction.py:447, in Instruction.__deepcopy__(self, memo)
#     444         cpy.name = name
#     445     return cpy
# --> 447 def __deepcopy__(self, memo=None):
#     448     cpy = copy.copy(self)
#     449     cpy._params = copy.copy(self._params)
#
# KeyboardInterrupt:

# %%
with open("run_trotter_"+str(num_qubits)+"-qubit_trotter.pkl", "wb") as f:
    pickle.dump({"num_steps_list": num_steps_list, "fidelities": fidelities, "nums_cnots": nums_cnots}, f)

# %%
plt.plot(num_steps_list, fidelities)
plt.xlabel("Trotter steps")
plt.ylabel("state fidelity")
plt.show()

# %%
qc = QuantumCircuit(num_qubits)

# Prepare initial state
qc.compose(gate_initial_state(state_initial=state_initial),
            qubits=list(range(num_qubits)),
            inplace=True,)

qc.append(instruction=gate_path_conventional(num_qubits=num_qubits,
                                        num_steps=1, ###!
                                        dt=dt,
                                        to_instruction=False,
                                        add_barrier=False,
                                        ),
            qargs=list(range(num_qubits)),
            )

# Evaluate simulation at target_time (t=pi) meaning each trotter step evolves pi/trotter_steps in time
qc = qc.assign_parameters({dt: time_evolution / num_steps})
# qc_t3 = transpile(RemoveBarriers()(qc), optimization_level=3, basis_gates=["sx", "cx", "rz"])
qc_t3 = transpile(qc, optimization_level=0, basis_gates=["sx", "cx", "rz"])
qc_t3.save_density_matrix()
qc_t3.draw("mpl")

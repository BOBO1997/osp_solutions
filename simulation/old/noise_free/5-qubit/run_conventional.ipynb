# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from pprint import pprint
import pickle
import time
import datetime

# %%
# Import qubit states Zero (|0>) and One (|1>), and Pauli operators (X, Y, Z)
from qiskit.circuit import QuantumCircuit, QuantumRegister, Parameter
# from qiskit.tools.monitor import job_monitor
from qiskit.compiler import transpile
from qiskit.transpiler.passes import RemoveBarriers

# %%
# Import state tomography modules
from qiskit_experiments.library import StateTomography
from osp_solutions.patch_ignis import rename_qcs_StateTomography_to_ignis
from osp_solutions.tomography import StateTomographyFitter
from qiskit.quantum_info import state_fidelity

# %%
from osp_solutions.circuits_initial import gate_initial_state
from osp_solutions.circuits_path import gate_path_proposed, gate_path_conventional
from osp_solutions.simulator_dm import make_dm_binary, hamiltonian_to_dm, DMExtended
from osp_solutions.hamiltonian import Hamiltonian, make_H_Heisenberg_path
from osp_solutions.backend_simulator import result_to_dms
from setting import *
# Out:
# NoiseModel:
#   Basis gates: ['cx', 'cz', 'h', 'id', 'rx', 'rz', 's', 'sdg', 'sx', 'u1', 'u2', 'u3', 'x']
#   Instructions with noise: ['u1', 'rz', 'cz', 'rx', 'u3', 'u2', 'x', 'cx', 'sdg', 'sx', 'h', 's']
#   All-qubits errors: ['rx', 'rz', 'sx', 'h', 'sdg', 's', 'x', 'u1', 'u2', 'u3', 'cx', 'cz']

# %%
dt = Parameter('t')
state_initial_dm = DMExtended(matrix=make_dm_binary(str_binary=state_initial,
                                                    endian_binary="big",
                                                    endian_dm="little")) ### make the density matrix for the initial state

H_Heisenberg = make_H_Heisenberg_path(num_qubits=num_qubits) ### create Heisenberg Hamiltonian in a dictionary format
matrix_Heisenberg = hamiltonian_to_dm(hamiltonian=H_Heisenberg) ### convert Heisenberg Hamiltonian to its matrix form

U_Heisenberg = DMExtended(sp.linalg.expm(-1.0j * matrix_Heisenberg * time_evolution)) ### prepare the unitary matrix of the Heisenberg Hamiltonian

state_target_dm = state_initial_dm.apply_unitary(U_Heisenberg) ### apply the unitary evolution to the density matrix
state_target_dm.is_valid()
# Out:
# True

# %%
fidelities = []
nums_cnots = []

print("trotter step list: ", num_steps_list)
for num_steps in num_steps_list:
    
    print("trotter steps: ", num_steps)
    t1 = time.perf_counter()
    
    # Initialize quantum circuit for 3 qubits
    qc = QuantumCircuit(num_qubits)

    # Prepare initial state
    qc.compose(gate_initial_state(state_initial=state_initial),
               qubits=list(range(num_qubits)),
               inplace=True,)
    
    qc.append(instruction=gate_path_conventional(num_qubits=num_qubits,
                                           num_steps=num_steps,
                                           dt=dt,
                                           to_instruction=False,
                                           add_barrier=False,
                                          ),
              qargs=list(range(num_qubits)),
             )

    # Evaluate simulation at target_time (t=pi) meaning each trotter step evolves pi/trotter_steps in time
    qc = qc.assign_parameters({dt: time_evolution / num_steps})
    qc_t3 = transpile(RemoveBarriers()(qc), optimization_level=3, basis_gates=["sx", "cx", "rz"])
    qc_t3.save_density_matrix()
    
    ### execute circuits
    result_raw = simulator_ideal.run(qc_t3,
                                     shots=0,
                                    ).result()
    dm_raw = result_to_dms(result=result_raw,
                           endian_result="little",
                           endian_dm="little",
                          )[0]

    fidelities.append(state_fidelity(dm_raw, state_target_dm))
    nums_cnots.append(qc_t3.count_ops().get("cx"))
    
    t2 = time.perf_counter()
    print("raw state tomography fidelity = {:.4f}".format(fidelities[-1]))
    print("number of CNOT gates:", qc_t3.count_ops().get("cx"))
    print("time:", t2 - t1)
    print()
# Out:
# trotter step list:  [4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64, 68, 72, 76, 80, 84, 88, 92, 96]
# trotter steps:  4
# raw state tomography fidelity = 0.0006
# number of CNOT gates: 48
# time: 0.01623187493532896
#
# trotter steps:  8
# raw state tomography fidelity = 0.4171
# number of CNOT gates: 96
# time: 0.014367791824042797
#
# trotter steps:  12
# raw state tomography fidelity = 0.7957
# number of CNOT gates: 144
# time: 0.016831499990075827
#
# trotter steps:  16
# raw state tomography fidelity = 0.8954
# number of CNOT gates: 192
# time: 0.021237917011603713
#
# trotter steps:  20
# raw state tomography fidelity = 0.9361
# number of CNOT gates: 240
# time: 0.025765292113646865
#
# trotter steps:  24
# raw state tomography fidelity = 0.9568
# number of CNOT gates: 288
# time: 0.028714749962091446
#
# trotter steps:  28
# raw state tomography fidelity = 0.9688
# number of CNOT gates: 336
# time: 0.033465041080489755
#
# trotter steps:  32
# raw state tomography fidelity = 0.9764
# number of CNOT gates: 384
# time: 0.03702383302152157
#
# trotter steps:  36
# raw state tomography fidelity = 0.9815
# number of CNOT gates: 432
# time: 0.042439083103090525
#
# trotter steps:  40
# raw state tomography fidelity = 0.9851
# number of CNOT gates: 480
# time: 0.045401667011901736
#
# trotter steps:  44
# raw state tomography fidelity = 0.9877
# number of CNOT gates: 528
# time: 0.04897866700775921
#
# trotter steps:  48
# raw state tomography fidelity = 0.9897
# number of CNOT gates: 576
# time: 0.05140916700474918
#
# trotter steps:  52
# raw state tomography fidelity = 0.9913
# number of CNOT gates: 624
# time: 0.05749945901334286
#
# trotter steps:  56
# raw state tomography fidelity = 0.9925
# number of CNOT gates: 672
# time: 0.062490041833370924
#
# trotter steps:  60
# raw state tomography fidelity = 0.9935
# number of CNOT gates: 720
# time: 0.06572262500412762
#
# trotter steps:  64
# raw state tomography fidelity = 0.9943
# number of CNOT gates: 768
# time: 0.06984558398835361
#
# trotter steps:  68
# raw state tomography fidelity = 0.9949
# number of CNOT gates: 816
# time: 0.07234091614373028
#
# trotter steps:  72
# raw state tomography fidelity = 0.9955
# number of CNOT gates: 864
# time: 0.0759858749806881
#
# trotter steps:  76
# raw state tomography fidelity = 0.9959
# number of CNOT gates: 912
# time: 0.08046466717496514
#
# trotter steps:  80
# raw state tomography fidelity = 0.9963
# number of CNOT gates: 960
# time: 0.08638804103247821
#
# trotter steps:  84
# raw state tomography fidelity = 0.9967
# number of CNOT gates: 1008
# time: 0.08924208395183086
#
# trotter steps:  88
# raw state tomography fidelity = 0.9970
# number of CNOT gates: 1056
# time: 0.0942027501296252
#
# trotter steps:  92
# raw state tomography fidelity = 0.9972
# number of CNOT gates: 1104
# time: 0.09810437494888902
#
# trotter steps:  96
# raw state tomography fidelity = 0.9975
# number of CNOT gates: 1152
# time: 0.10206750012002885

# %%
with open("run_conventional.pkl", "wb") as f:
    pickle.dump(obj={"num_steps_list": num_steps_list, 
                     "fidelities": fidelities, 
                     "nums_cnots": nums_cnots}, 
                file=f)

# %%
plt.plot(num_steps_list, fidelities)
plt.xlabel("Trotter steps")
plt.ylabel("state fidelity")
plt.show()

# %%
qc = QuantumCircuit(num_qubits)

# Prepare initial state
qc.compose(gate_initial_state(state_initial=state_initial),
            qubits=list(range(num_qubits)),
            inplace=True,)

qc.append(instruction=gate_path_conventional(num_qubits=num_qubits,
                                        num_steps=1, ###!
                                        dt=dt,
                                        to_instruction=False,
                                        add_barrier=False,
                                        ),
            qargs=list(range(num_qubits)),
            )

# Evaluate simulation at target_time (t=pi) meaning each trotter step evolves pi/trotter_steps in time
qc = qc.assign_parameters({dt: time_evolution / num_steps})
# qc_t3 = transpile(RemoveBarriers()(qc), optimization_level=3, basis_gates=["sx", "cx", "rz"])
qc_t3 = transpile(qc, optimization_level=0, basis_gates=["sx", "cx", "rz"])
qc_t3.save_density_matrix()
qc_t3.draw("mpl")

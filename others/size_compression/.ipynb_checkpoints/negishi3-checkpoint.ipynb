# %% [markdown]
# # Import Libiraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import itertools
plt.rcParams.update({'font.size': 16})  # enlarge matplotlib fonts

# %%
# Import qubit states Zero (|0>) and One (|1>), and Pauli operators (X, Y, Z)
# from qiskit.opflow import Zero, One, I, X, Y, Z
from qiskit import QuantumCircuit, QuantumRegister, IBMQ, execute, transpile, Aer
from qiskit.providers.aer import QasmSimulator
from qiskit.tools.monitor import job_monitor
from qiskit.circuit import Parameter

# %%
# Import QREM package
from qiskit.ignis.mitigation.measurement import complete_meas_cal, CompleteMeasFitter
# Out:
# /var/folders/vr/d82vcp297v78vk4sb0_nzzdc0000gn/T/ipykernel_28784/4110962823.py:2: DeprecationWarning: The qiskit.ignis package is deprecated and has been supersceded by the qiskit-experiments project. Refer to the migration guide: https://github.com/Qiskit/qiskit-ignis#migration-guide on how to migrate to the new project.
#   from qiskit.ignis.mitigation.measurement import complete_meas_cal, CompleteMeasFitter

# %%
# Import mitiq for zne
import mitiq

# %%
# Import state tomography modules
from qiskit.ignis.verification.tomography import state_tomography_circuits, StateTomographyFitter
from qiskit.quantum_info import state_fidelity

# %%
# Suppress warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Trotter Gate

# %%
def trotter_gate(dt, to_instruction = True):
    qc = QuantumCircuit(2)
    qc.rx(2*dt,0)
    qc.rz(2*dt,1)
    qc.h(1)
    qc.cx(1,0)
    qc.rz(-2*dt, 0)
    qc.rx(-2*dt, 1)
    qc.rz(2*dt, 1)
    qc.cx(1,0)
    qc.h(1)
    qc.rz(2*dt, 0)
    return qc.to_instruction() if to_instruction else qc

# %%
trotter_gate(np.pi / 6, to_instruction=False).draw("mpl")

# %% [markdown]
# # Set Parameters

# %%
# Combine subcircuits into a single multiqubit gate representing a single trotter step
num_qubits = 3

# The final time of the state evolution
target_time = np.pi

# Parameterize variable t to be evaluated at t=pi later
dt = Parameter('t')
# Convert custom quantum circuit into a gate
Trot_gate = trotter_gate(dt)

# Number of trotter steps
trotter_steps = 15  ### CAN BE >= 4

# %% [markdown]
# # Make Quantum Circuit

# %%
# Initialize quantum circuit for 3 qubits
qr = QuantumRegister(7)
qc = QuantumCircuit(qr)

# Prepare initial state (remember we are only evolving 3 of the 7 qubits on jakarta qubits (q_5, q_3, q_1) corresponding to the state |110>)
qc.x([5])  # DO NOT MODIFY (|q_5,q_3,q_1> = |110>)

# Simulate time evolution under H_heis3 Hamiltonian
for _ in range(trotter_steps):
    qc.append(Trot_gate, [qr[3], qr[5]])

qc.cx(qr[3], qr[1])
qc.cx(qr[5], qr[3])

# Evaluate simulation at target_time (t=pi) meaning each trotter step evolves pi/trotter_steps in time
qc = qc.bind_parameters({dt: target_time/trotter_steps})
t3_qc = transpile(qc, optimization_level=3, basis_gates=["sx", "cx", "rz"])

# %%
# Generate state tomography circuits to evaluate fidelity of simulation
st_qcs = state_tomography_circuits(t3_qc, [qr[1], qr[3], qr[5]])

# %%
# Display circuit for confirmation
# st_qcs[-1].decompose().draw()  # view decomposition of trotter gates
st_qcs[-1].draw("mpl")  # only view trotter gates

# %% [markdown]
# xxx
# xxy
# xxz
# xyx
# xyy
# xyz
# xzx
# xzy
# xzz
# yxx
# yxy
# yxz
# yyx
# yyy
# yyz
# ...
# zzz

# %%
st_qcs[13].draw("mpl")

# %%
# Pauli Twirling
# TODO: 一度挙動を調べる
def pauli_twirling(circ: str) -> QuantumCircuit:
    """
    そのまま使う: 修正は後回し
    """
    #! qasm ベタ書き
    def apply_pauli(num: int, qb: int) -> str:
        if (num == 0):
            return f'id q[{qb}];\n'
        elif (num == 1):
            return f'x q[{qb}];\n'
        elif (num == 2):
            return f'y q[{qb}];\n'
        else:
            return f'z q[{qb}];\n'

    paulis = [(i,j) for i in range(0,4) for j in range(0,4)]
    paulis.remove((0,0))
    paulis_map = [(0, 1), (3, 2), (3, 3), (1, 1), (1, 0), (2, 3), (2, 2), (2, 1), (2, 0), (1, 3), (1, 2), (3, 0), (3, 1), (0, 2), (0, 3)]

    new_circ = ''
    ops = circ.qasm().splitlines(True) #! 生のqasmコードを持ってきてる: オペレータに分解
    for op in ops:
        if (op[:2] == 'cx'): # can add for cz, etc.
            num = random.randrange(len(paulis)) #! permute paulis
            qbs = re.findall('q\[(.)\]', op)
            new_circ += apply_pauli(paulis[num][0], qbs[0])
            new_circ += apply_pauli(paulis[num][1], qbs[1])
            new_circ += op
            new_circ += apply_pauli(paulis_map[num][0], qbs[0])
            new_circ += apply_pauli(paulis_map[num][1], qbs[1])
        else:
            new_circ += op
    return qiskit.circuit.QuantumCircuit.from_qasm_str(new_circ)

# %%
# ZNE
# 3種類の実行方法
# 1. state tomography回路全体をzne
# 2. state tomography前の回路をzne
# 3. 2-qubitの状態だけzne
# 今回は1を実装する
def zne_wrapper(qcs, scale_factors = [1.0, 2.0, 3.0]):
    """
    """
    folded_qcs = [] #! ZNE用の回路
    for qc in qcs:
        folded_qcs.append([mitiq.zne.scaling.fold_gates_at_random(qc, scale) for scale in scale_factors]) #! ここでmitiqを使用
    folded_qcs = list(itertools.chain(*folded_qcs)) #! folded_qcsを平坦化
    folded_qcs = [pauli_twirling(circ) for circ in folded_qcs] #! 後からPauli Twirlingを施す!
    return folded_qcs

# %% [markdown]
# # Subspace Expansion
#
# Require $K \times K$ circuits for $K$個の項の重ね合わせ
#
# つまり、合計で、$K^2\times Z \times 27$ 個の回路が必要。
# $K = Z = 3$とすると、$27 \times 27 = 729$ 個の回路が必要。
#
# ## TODO
#
# - ZNEの中にsubspace expansionを入れるか、subspace expansionの中にZNEを入れるか
# - 個人的には後者がいい: zneでstochastic errorを抑えて(←ほんまか？)、その値でcoherent error (algorithmic error)を抑える方が合理的

# %%
# subspace expansion
# TODO: 実装はとりあえず後回し
def se_wrapper(qcs):
    """
    """
    folded_qcs = []
    for qc in qcs:
        pass
    return folded_qcs

# %%
from qiskit.test.mock import FakeJakarta
backend = FakeJakarta()
# backend = Aer.get_backend("qasm_simulator")
# backend = provider.get_backend("ibmq_jakarta")

# %%
shots = 8192
reps = 8

# %%
jobs = []
for _ in range(reps):
    # execute
    job = execute(st_qcs, backend, shots=shots)
    print('Job ID', job.job_id())
    jobs.append(job)
# Out:
# Job ID dff31304-2ef1-49df-9a8a-875ef4ab856a
# Job ID 972f75d4-6281-484a-b45b-c6a03e62c60a
# Job ID bb17cedf-381c-418d-897e-904a9c77675f
# Job ID 45081350-9c8c-482b-b8a7-1f623012afc8
# Job ID 693cb925-c2f1-4d5c-a210-8efd963cf356
# Job ID 8bdaaee5-df1e-4f9a-bd89-91eb2e28288a
# Job ID 09a144fa-a958-4668-9d88-a3ef896b23ef
# Job ID ca423e51-18f7-4f69-91f4-476ddc481eb2

# %%
# QREM
qr = QuantumRegister(num_qubits)
meas_calibs, state_labels = complete_meas_cal(qr=qr, circlabel='mcal')
cal_job = execute(meas_calibs, backend=backend, shots=shots, optimization_level=3)
cal_results = cal_job.result()
meas_fitter = CompleteMeasFitter(cal_results, state_labels, circlabel='mcal')

# %% [markdown]
# # Reimplement State Tomography
#
# $$\rho=\sum_{\vec{v}} \frac{\operatorname{tr}\left(\sigma_{v_{1}} \otimes \sigma_{v_{2}} \otimes \cdots \otimes \sigma_{v_{n}} \rho\right) \sigma_{v_{1}} \otimes \sigma_{v_{2}} \otimes \cdots \otimes \sigma_{v_{n}}}{2^{n}}$$
# where the sum is over vectors $\vec{v}=\left(v_{1}, \ldots, v_{n}\right)$ with entries $v_i$ chosen from the set $0, 1, 2, 3$.

# %%
def make_basis(n):
    basis = np.zeros((1 << n, n), dtype="int")
    return basis

# %%
def measurement_basis(v):
    I = np.array([[1,0],[0,1]], dtype="complex")
    X = np.array([[0,1],[1,0]], dtype="complex")
    Y = np.array([[0,-1j],[1j,0]], dtype="complex")
    Z = np.array([[1,0],[0,-1]], dtype="complex")
    ret = I
    for i in v:
        if i == 0:
            ret = np.kron(ret, I)
        elif i == 1:
            ret = np.kron(ret, X)
        elif i == 2:
            ret = np.kron(ret, Y)
        elif i == 3:
            ret = np.kron(ret, Z)
        else:
            raise Exception
    return ret

# %%
def state_tomography(n, expvals, vs):
    rho = np.zeros((1 << n, 1 << n), dtype="complex")
    for i, v in enumerate(vs):
        rho += expvals[i] * measurement_basis(v)
    return rho / (1 << n)

# %%
# Compute the state tomography based on the st_qcs quantum circuits and the results from those ciricuits
def state_tomo(expvals, st_qcs):
    # The expected final state; necessary to determine state tomography fidelity
    target_state = (One^One^Zero).to_matrix()  # DO NOT MODIFY (|q_5,q_3,q_1> = |110>)
    # Fit state tomography results
    tomo_fitter = StateTomographyFitter(result, st_qcs)
    rho_fit = tomo_fitter.fit(method='lstsq')
    # Compute fidelity
    fid = state_fidelity(rho_fit, target_state)
    return fid

# %%
stf = StateTomographyFitter(job.result(), st_qcs)
stf._data
# Out:
# {('X', 'X', 'X'): {'101': 1100,
#   '001': 1017,
#   '110': 958,
#   '100': 933,
#   '000': 1086,
#   '010': 1188,
#   '111': 933,
#   '011': 977},
#  ('X', 'X', 'Y'): {'011': 820,
#   '111': 1085,
#   '001': 943,
#   '110': 868,
#   '100': 853,
#   '000': 1165,
#   '010': 1279,
#   '101': 1179},
#  ('X', 'X', 'Z'): {'111': 1713,
#   '011': 215,
#   '001': 228,
#   '100': 1826,
#   '110': 1915,
#   '000': 228,
#   '010': 247,
#   '101': 1820},
#  ('X', 'Y', 'X'): {'111': 880,
#   '011': 969,
#   '101': 1136,
#   '100': 911,
#   '001': 1094,
#   '110': 1043,
#   '010': 1113,
#   '000': 1046},
#  ('X', 'Y', 'Y'): {'011': 802,
#   '111': 974,
#   '001': 998,
#   '100': 827,
#   '110': 920,
#   '101': 1172,
#   '010': 1291,
#   '000': 1208},
#  ('X', 'Y', 'Z'): {'000': 233,
#   '010': 237,
#   '011': 216,
#   '111': 1613,
#   '001': 228,
#   '100': 1745,
#   '110': 1990,
#   '101': 1930},
#  ('X', 'Z', 'X'): {'011': 1834,
#   '111': 1869,
#   '101': 131,
#   '000': 192,
#   '010': 2031,
#   '100': 194,
#   '001': 172,
#   '110': 1769},
#  ('X', 'Z', 'Y'): {'100': 193,
#   '001': 163,
#   '110': 1555,
#   '000': 169,
#   '010': 2254,
#   '101': 176,
#   '011': 1623,
#   '111': 2059},
#  ('X', 'Z', 'Z'): {'000': 145,
#   '010': 295,
#   '101': 226,
#   '001': 124,
#   '100': 210,
#   '110': 3470,
#   '011': 296,
#   '111': 3426},
#  ('Y', 'X', 'X'): {'101': 808,
#   '100': 1235,
#   '001': 1050,
#   '110': 1124,
#   '111': 898,
#   '011': 1210,
#   '010': 871,
#   '000': 996},
#  ('Y', 'X', 'Y'): {'101': 959,
#   '001': 934,
#   '110': 947,
#   '100': 1021,
#   '011': 1039,
#   '111': 1091,
#   '000': 1188,
#   '010': 1013},
#  ('Y', 'X', 'Z'): {'001': 220,
#   '100': 2029,
#   '110': 1674,
#   '101': 1678,
#   '000': 217,
#   '010': 214,
#   '011': 228,
#   '111': 1932},
#  ('Y', 'Y', 'X'): {'101': 885,
#   '110': 1172,
#   '001': 1234,
#   '100': 1161,
#   '010': 954,
#   '000': 909,
#   '111': 779,
#   '011': 1098},
#  ('Y', 'Y', 'Y'): {'100': 928,
#   '110': 1037,
#   '001': 1006,
#   '011': 897,
#   '111': 1023,
#   '101': 1027,
#   '010': 1137,
#   '000': 1137},
#  ('Y', 'Y', 'Z'): {'010': 233,
#   '000': 228,
#   '111': 1628,
#   '011': 219,
#   '101': 1935,
#   '001': 234,
#   '110': 1974,
#   '100': 1741},
#  ('Y', 'Z', 'X'): {'101': 140,
#   '001': 181,
#   '110': 2064,
#   '100': 168,
#   '111': 1579,
#   '011': 2167,
#   '000': 179,
#   '010': 1714},
#  ('Y', 'Z', 'Y'): {'101': 172,
#   '011': 1753,
#   '111': 1946,
#   '010': 2028,
#   '000': 225,
#   '001': 154,
#   '100': 178,
#   '110': 1736},
#  ('Y', 'Z', 'Z'): {'101': 216,
#   '100': 229,
#   '110': 3501,
#   '001': 129,
#   '111': 3367,
#   '011': 314,
#   '000': 132,
#   '010': 304},
#  ('Z', 'X', 'X'): {'111': 114,
#   '011': 133,
#   '101': 129,
#   '001': 121,
#   '100': 1932,
#   '110': 1811,
#   '010': 1966,
#   '000': 1986},
#  ('Z', 'X', 'Y'): {'111': 113,
#   '011': 131,
#   '110': 1802,
#   '100': 1913,
#   '001': 132,
#   '101': 146,
#   '000': 1973,
#   '010': 1982},
#  ('Z', 'X', 'Z'): {'011': 110,
#   '111': 148,
#   '001': 142,
#   '110': 3400,
#   '100': 3601,
#   '101': 147,
#   '010': 321,
#   '000': 323},
#  ('Z', 'Y', 'X'): {'101': 129,
#   '111': 130,
#   '011': 132,
#   '001': 129,
#   '100': 1937,
#   '110': 1827,
#   '000': 2016,
#   '010': 1892},
#  ('Z', 'Y', 'Y'): {'011': 145,
#   '111': 118,
#   '001': 142,
#   '110': 1860,
#   '100': 1958,
#   '101': 132,
#   '010': 1876,
#   '000': 1961},
#  ('Z', 'Y', 'Z'): {'011': 140,
#   '111': 132,
#   '001': 117,
#   '110': 3452,
#   '100': 3559,
#   '101': 134,
#   '010': 351,
#   '000': 307},
#  ('Z', 'Z', 'X'): {'101': 96,
#   '011': 160,
#   '111': 152,
#   '001': 106,
#   '100': 234,
#   '110': 3505,
#   '000': 246,
#   '010': 3693},
#  ('Z', 'Z', 'Y'): {'101': 115,
#   '001': 108,
#   '110': 3525,
#   '100': 228,
#   '111': 146,
#   '011': 154,
#   '000': 240,
#   '010': 3676},
#  ('Z', 'Z', 'Z'): {'011': 211,
#   '111': 80,
#   '101': 199,
#   '010': 396,
#   '000': 231,
#   '001': 29,
#   '100': 259,
#   '110': 6787}}

# %%
from IPython.core.debugger import Pdb; Pdb().set_trace()
data, basis_matrix, weights = stf._fitter_data(True, 0.5)
# Out:
# --Return--
# None
# > /var/folders/vr/d82vcp297v78vk4sb0_nzzdc0000gn/T/ipykernel_28784/2411698869.py(1)<module>()
# ----> 1 from IPython.core.debugger import Pdb; Pdb().set_trace()
#       2 data, basis_matrix, weights = stf._fitter_data(True, 0.5)
#
# ipdb> b 2
# Breakpoint 1 at /var/folders/vr/d82vcp297v78vk4sb0_nzzdc0000gn/T/ipykernel_28784/2411698869.py:2
# ipdb> c
# None
# > /var/folders/vr/d82vcp297v78vk4sb0_nzzdc0000gn/T/ipykernel_28784/2411698869.py(2)<module>()
#       1 from IPython.core.debugger import Pdb; Pdb().set_trace()
# 1---> 2 data, basis_matrix, weights = stf._fitter_data(True, 0.5)
#
# ipdb> s
# --Call--
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(289)_fitter_data()
#     287                 self._data[tup] = counts
#     288
# --> 289     def _fitter_data(self, standard_weights, beta):
#     290         """Generate tomography fitter data from a tomography data dictionary.
#     291
#
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(314)_fitter_data()
#     312         """
#     313         # Get basis matrix functions
# --> 314         if self._meas_basis:
#     315             measurement = self._meas_basis.measurement_matrix
#     316         else:
#
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(315)_fitter_data()
#     313         # Get basis matrix functions
#     314         if self._meas_basis:
# --> 315             measurement = self._meas_basis.measurement_matrix
#     316         else:
#     317             measurement = None
#
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(318)_fitter_data()
#     316         else:
#     317             measurement = None
# --> 318         if self._prep_basis:
#     319             preparation = self._prep_basis.preparation_matrix
#     320         else:
#
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(321)_fitter_data()
#     319             preparation = self._prep_basis.preparation_matrix
#     320         else:
# --> 321             preparation = None
#     322
#     323         data = []
#
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(323)_fitter_data()
#     321             preparation = None
#     322
# --> 323         data = []
#     324         basis_blocks = []
#     325         if standard_weights:
#
# ipdb> preparation
# ipdb> measurement
# <bound method TomographyBasis.measurement_matrix of <qiskit.ignis.verification.tomography.basis.tomographybasis.TomographyBasis object at 0x7fde5201eb80>>
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(324)_fitter_data()
#     322
#     323         data = []
# --> 324         basis_blocks = []
#     325         if standard_weights:
#     326             weights = []
#
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(325)_fitter_data()
#     323         data = []
#     324         basis_blocks = []
# --> 325         if standard_weights:
#     326             weights = []
#     327         else:
#
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(326)_fitter_data()
#     324         basis_blocks = []
#     325         if standard_weights:
# --> 326             weights = []
#     327         else:
#     328             weights = None
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(332)_fitter_data()
#     330         # Check if input data is state or process tomography data based
#     331         # on the label tuples
# --> 332         label = next(iter(self._data))
#     333         is_qpt = (isinstance(label, tuple) and len(label) == 2 and
#     334                   isinstance(label[0], tuple) and isinstance(label[1], tuple))
#
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(333)_fitter_data()
#     331         # on the label tuples
#     332         label = next(iter(self._data))
# --> 333         is_qpt = (isinstance(label, tuple) and len(label) == 2 and
#     334                   isinstance(label[0], tuple) and isinstance(label[1], tuple))
#     335         # Generate counts keys for converting to np array
#
# ipdb> label
# ('X', 'X', 'X')
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(333)_fitter_data()
#     331         # on the label tuples
#     332         label = next(iter(self._data))
# --> 333         is_qpt = (isinstance(label, tuple) and len(label) == 2 and
#     334                   isinstance(label[0], tuple) and isinstance(label[1], tuple))
#     335         # Generate counts keys for converting to np array
#
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(336)_fitter_data()
#     334                   isinstance(label[0], tuple) and isinstance(label[1], tuple))
#     335         # Generate counts keys for converting to np array
# --> 336         if is_qpt:
#     337             ctkeys = count_keys(len(label[1]))
#     338         else:
#
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(339)_fitter_data()
#     337             ctkeys = count_keys(len(label[1]))
#     338         else:
# --> 339             ctkeys = count_keys(len(label))
#     340         for label, cts in self._data.items():
#     341
#
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(340)_fitter_data()
#     338         else:
#     339             ctkeys = count_keys(len(label))
# --> 340         for label, cts in self._data.items():
#     341
#     342             # Convert counts dict to numpy array
#
# ipdb> ctkeys
# ['000', '001', '010', '011', '100', '101', '110', '111']
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(343)_fitter_data()
#     341
#     342             # Convert counts dict to numpy array
# --> 343             if isinstance(cts, dict):
#     344                 cts = np.array([cts.get(key, 0) for key in ctkeys])
#     345
#
# ipdb> label
# ('X', 'X', 'X')
# ipdb> cts
# {'101': 1100, '001': 1017, '110': 958, '100': 933, '000': 1086, '010': 1188, '111': 933, '011': 977}
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(344)_fitter_data()
#     342             # Convert counts dict to numpy array
#     343             if isinstance(cts, dict):
# --> 344                 cts = np.array([cts.get(key, 0) for key in ctkeys])
#     345
#     346             # Get probabilities
#
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(347)_fitter_data()
#     345
#     346             # Get probabilities
# --> 347             shots = np.sum(cts)
#     348             probs = np.array(cts) / shots
#     349             data += list(probs)
#
# ipdb> cts
# array([1086, 1017, 1188,  977,  933, 1100,  958,  933])
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(348)_fitter_data()
#     346             # Get probabilities
#     347             shots = np.sum(cts)
# --> 348             probs = np.array(cts) / shots
#     349             data += list(probs)
#     350
# ipdb> shots
# 8192
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(349)_fitter_data()
#     347             shots = np.sum(cts)
#     348             probs = np.array(cts) / shots
# --> 349             data += list(probs)
#     350
#     351             # Compute binomial weights
#
# ipdb> probs
# array([0.13256836, 0.12414551, 0.14501953, 0.1192627 , 0.1138916 ,
#        0.13427734, 0.11694336, 0.1138916 ])
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(352)_fitter_data()
#     350
#     351             # Compute binomial weights
# --> 352             if standard_weights is True:
#     353                 wts = self._binomial_weights(cts, beta)
#     354                 weights += list(wts)
#
# ipdb> data
# [0.132568359375, 0.1241455078125, 0.14501953125, 0.1192626953125, 0.1138916015625, 0.13427734375, 0.116943359375, 0.1138916015625]
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(353)_fitter_data()
#     351             # Compute binomial weights
#     352             if standard_weights is True:
# --> 353                 wts = self._binomial_weights(cts, beta)
#     354                 weights += list(wts)
#     355
#
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(354)_fitter_data()
#     352             if standard_weights is True:
#     353                 wts = self._binomial_weights(cts, beta)
# --> 354                 weights += list(wts)
#     355
#     356             # Get reconstruction basis operators
#
# ipdb> wts
# array([266.90857519, 274.48136211, 257.04891514, 279.26406676,
#        284.90278047, 265.46691073, 281.64793705, 284.90278047])
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(357)_fitter_data()
#     355
#     356             # Get reconstruction basis operators
# --> 357             if is_qpt:
#     358                 prep_label = label[0]
#     359                 meas_label = label[1]
#
# ipdb> weights
# [266.90857518676074, 274.4813621120242, 257.04891514264074, 279.26406675886, 284.9027804733516, 265.4669107251381, 281.6479370548739, 284.9027804733516]
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(361)_fitter_data()
#     359                 meas_label = label[1]
#     360             else:
# --> 361                 prep_label = None
#     362                 meas_label = label
#     363             prep_op = self._preparation_op(prep_label, preparation)
#
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(362)_fitter_data()
#     360             else:
#     361                 prep_label = None
# --> 362                 meas_label = label
#     363             prep_op = self._preparation_op(prep_label, preparation)
#     364             meas_ops = self._measurement_ops(meas_label, measurement)
#
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(363)_fitter_data()
#     361                 prep_label = None
#     362                 meas_label = label
# --> 363             prep_op = self._preparation_op(prep_label, preparation)
#     364             meas_ops = self._measurement_ops(meas_label, measurement)
#     365             block = self._basis_operator_matrix(
#
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(364)_fitter_data()
#     362                 meas_label = label
#     363             prep_op = self._preparation_op(prep_label, preparation)
# --> 364             meas_ops = self._measurement_ops(meas_label, measurement)
#     365             block = self._basis_operator_matrix(
#     366                 [np.kron(prep_op.T, mop) for mop in meas_ops])
# ipdb> prep_op
# array([[1.+0.j]])
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(365)_fitter_data()
#     363             prep_op = self._preparation_op(prep_label, preparation)
#     364             meas_ops = self._measurement_ops(meas_label, measurement)
# --> 365             block = self._basis_operator_matrix(
#     366                 [np.kron(prep_op.T, mop) for mop in meas_ops])
#     367             basis_blocks.append(block)
#
# ipdb> meas_ops
# [array([[0.125+0.j, 0.125+0.j, 0.125+0.j, 0.125+0.j, 0.125+0.j, 0.125+0.j,
#         0.125+0.j, 0.125+0.j],
#        [0.125+0.j, 0.125+0.j, 0.125+0.j, 0.125+0.j, 0.125+0.j, 0.125+0.j,
#         0.125+0.j, 0.125+0.j],
#        [0.125+0.j, 0.125+0.j, 0.125+0.j, 0.125+0.j, 0.125+0.j, 0.125+0.j,
#         0.125+0.j, 0.125+0.j],
#        [0.125+0.j, 0.125+0.j, 0.125+0.j, 0.125+0.j, 0.125+0.j, 0.125+0.j,
#         0.125+0.j, 0.125+0.j],
#        [0.125+0.j, 0.125+0.j, 0.125+0.j, 0.125+0.j, 0.125+0.j, 0.125+0.j,
#         0.125+0.j, 0.125+0.j],
#        [0.125+0.j, 0.125+0.j, 0.125+0.j, 0.125+0.j, 0.125+0.j, 0.125+0.j,
#         0.125+0.j, 0.125+0.j],
#        [0.125+0.j, 0.125+0.j, 0.125+0.j, 0.125+0.j, 0.125+0.j, 0.125+0.j,
#         0.125+0.j, 0.125+0.j],
#        [0.125+0.j, 0.125+0.j, 0.125+0.j, 0.125+0.j, 0.125+0.j, 0.125+0.j,
#         0.125+0.j, 0.125+0.j]]), array([[ 0.125+0.j, -0.125+0.j,  0.125+0.j, -0.125+0.j,  0.125+0.j,
#         -0.125+0.j,  0.125+0.j, -0.125+0.j],
#        [-0.125+0.j,  0.125+0.j, -0.125+0.j,  0.125+0.j, -0.125+0.j,
#          0.125+0.j, -0.125+0.j,  0.125+0.j],
#        [ 0.125+0.j, -0.125+0.j,  0.125+0.j, -0.125+0.j,  0.125+0.j,
#         -0.125+0.j,  0.125+0.j, -0.125+0.j],
#        [-0.125+0.j,  0.125+0.j, -0.125+0.j,  0.125+0.j, -0.125+0.j,
#          0.125+0.j, -0.125+0.j,  0.125+0.j],
#        [ 0.125+0.j, -0.125+0.j,  0.125+0.j, -0.125+0.j,  0.125+0.j,
#         -0.125+0.j,  0.125+0.j, -0.125+0.j],
#        [-0.125+0.j,  0.125+0.j, -0.125+0.j,  0.125+0.j, -0.125+0.j,
#          0.125+0.j, -0.125+0.j,  0.125+0.j],
#        [ 0.125+0.j, -0.125+0.j,  0.125+0.j, -0.125+0.j,  0.125+0.j,
#         -0.125+0.j,  0.125+0.j, -0.125+0.j],
#        [-0.125+0.j,  0.125+0.j, -0.125+0.j,  0.125+0.j, -0.125+0.j,
#          0.125+0.j, -0.125+0.j,  0.125+0.j]]), array([[ 0.125+0.j,  0.125+0.j, -0.125+0.j, -0.125+0.j,  0.125+0.j,
#          0.125+0.j, -0.125+0.j, -0.125+0.j],
#        [ 0.125+0.j,  0.125+0.j, -0.125+0.j, -0.125+0.j,  0.125+0.j,
#          0.125+0.j, -0.125+0.j, -0.125+0.j],
#        [-0.125+0.j, -0.125+0.j,  0.125+0.j,  0.125+0.j, -0.125+0.j,
#         -0.125+0.j,  0.125+0.j,  0.125+0.j],
#        [-0.125+0.j, -0.125+0.j,  0.125+0.j,  0.125+0.j, -0.125+0.j,
#         -0.125+0.j,  0.125+0.j,  0.125+0.j],
#        [ 0.125+0.j,  0.125+0.j, -0.125+0.j, -0.125+0.j,  0.125+0.j,
#          0.125+0.j, -0.125+0.j, -0.125+0.j],
#        [ 0.125+0.j,  0.125+0.j, -0.125+0.j, -0.125+0.j,  0.125+0.j,
#          0.125+0.j, -0.125+0.j, -0.125+0.j],
#        [-0.125+0.j, -0.125+0.j,  0.125+0.j,  0.125+0.j, -0.125+0.j,
#         -0.125+0.j,  0.125+0.j,  0.125+0.j],
#        [-0.125+0.j, -0.125+0.j,  0.125+0.j,  0.125+0.j, -0.125+0.j,
#         -0.125+0.j,  0.125+0.j,  0.125+0.j]]), array([[ 0.125+0.j, -0.125+0.j, -0.125+0.j,  0.125-0.j,  0.125+0.j,
#         -0.125+0.j, -0.125+0.j,  0.125-0.j],
#        [-0.125+0.j,  0.125+0.j,  0.125-0.j, -0.125+0.j, -0.125+0.j,
#          0.125+0.j,  0.125-0.j, -0.125+0.j],
#        [-0.125+0.j,  0.125-0.j,  0.125+0.j, -0.125+0.j, -0.125+0.j,
#          0.125-0.j,  0.125+0.j, -0.125+0.j],
#        [ 0.125-0.j, -0.125+0.j, -0.125+0.j,  0.125+0.j,  0.125-0.j,
#         -0.125+0.j, -0.125+0.j,  0.125+0.j],
#        [ 0.125+0.j, -0.125+0.j, -0.125+0.j,  0.125-0.j,  0.125+0.j,
#         -0.125+0.j, -0.125+0.j,  0.125-0.j],
#        [-0.125+0.j,  0.125+0.j,  0.125-0.j, -0.125+0.j, -0.125+0.j,
#          0.125+0.j,  0.125-0.j, -0.125+0.j],
#        [-0.125+0.j,  0.125-0.j,  0.125+0.j, -0.125+0.j, -0.125+0.j,
#          0.125-0.j,  0.125+0.j, -0.125+0.j],
#        [ 0.125-0.j, -0.125+0.j, -0.125+0.j,  0.125+0.j,  0.125-0.j,
#         -0.125+0.j, -0.125+0.j,  0.125+0.j]]), array([[ 0.125+0.j,  0.125+0.j,  0.125+0.j,  0.125+0.j, -0.125+0.j,
#         -0.125+0.j, -0.125+0.j, -0.125+0.j],
#        [ 0.125+0.j,  0.125+0.j,  0.125+0.j,  0.125+0.j, -0.125+0.j,
#         -0.125+0.j, -0.125+0.j, -0.125+0.j],
#        [ 0.125+0.j,  0.125+0.j,  0.125+0.j,  0.125+0.j, -0.125+0.j,
#         -0.125+0.j, -0.125+0.j, -0.125+0.j],
#        [ 0.125+0.j,  0.125+0.j,  0.125+0.j,  0.125+0.j, -0.125+0.j,
#         -0.125+0.j, -0.125+0.j, -0.125+0.j],
#        [-0.125+0.j, -0.125+0.j, -0.125+0.j, -0.125+0.j,  0.125+0.j,
#          0.125+0.j,  0.125+0.j,  0.125+0.j],
#        [-0.125+0.j, -0.125+0.j, -0.125+0.j, -0.125+0.j,  0.125+0.j,
#          0.125+0.j,  0.125+0.j,  0.125+0.j],
#        [-0.125+0.j, -0.125+0.j, -0.125+0.j, -0.125+0.j,  0.125+0.j,
#          0.125+0.j,  0.125+0.j,  0.125+0.j],
#        [-0.125+0.j, -0.125+0.j, -0.125+0.j, -0.125+0.j,  0.125+0.j,
#          0.125+0.j,  0.125+0.j,  0.125+0.j]]), array([[ 0.125+0.j, -0.125+0.j,  0.125+0.j, -0.125+0.j, -0.125+0.j,
#          0.125-0.j, -0.125+0.j,  0.125-0.j],
#        [-0.125+0.j,  0.125+0.j, -0.125+0.j,  0.125+0.j,  0.125-0.j,
#         -0.125+0.j,  0.125-0.j, -0.125+0.j],
#        [ 0.125+0.j, -0.125+0.j,  0.125+0.j, -0.125+0.j, -0.125+0.j,
#          0.125-0.j, -0.125+0.j,  0.125-0.j],
#        [-0.125+0.j,  0.125+0.j, -0.125+0.j,  0.125+0.j,  0.125-0.j,
#         -0.125+0.j,  0.125-0.j, -0.125+0.j],
#        [-0.125+0.j,  0.125-0.j, -0.125+0.j,  0.125-0.j,  0.125+0.j,
#         -0.125+0.j,  0.125+0.j, -0.125+0.j],
#        [ 0.125-0.j, -0.125+0.j,  0.125-0.j, -0.125+0.j, -0.125+0.j,
#          0.125+0.j, -0.125+0.j,  0.125+0.j],
#        [-0.125+0.j,  0.125-0.j, -0.125+0.j,  0.125-0.j,  0.125+0.j,
#         -0.125+0.j,  0.125+0.j, -0.125+0.j],
#        [ 0.125-0.j, -0.125+0.j,  0.125-0.j, -0.125+0.j, -0.125+0.j,
#          0.125+0.j, -0.125+0.j,  0.125+0.j]]), array([[ 0.125+0.j,  0.125+0.j, -0.125+0.j, -0.125+0.j, -0.125+0.j,
#         -0.125+0.j,  0.125+0.j,  0.125+0.j],
#        [ 0.125+0.j,  0.125+0.j, -0.125+0.j, -0.125+0.j, -0.125+0.j,
#         -0.125+0.j,  0.125+0.j,  0.125+0.j],
#        [-0.125+0.j, -0.125+0.j,  0.125+0.j,  0.125+0.j,  0.125+0.j,
#          0.125+0.j, -0.125+0.j, -0.125+0.j],
#        [-0.125+0.j, -0.125+0.j,  0.125+0.j,  0.125+0.j,  0.125+0.j,
#          0.125+0.j, -0.125+0.j, -0.125+0.j],
#        [-0.125+0.j, -0.125+0.j,  0.125+0.j,  0.125+0.j,  0.125+0.j,
#          0.125+0.j, -0.125+0.j, -0.125+0.j],
#        [-0.125+0.j, -0.125+0.j,  0.125+0.j,  0.125+0.j,  0.125+0.j,
#          0.125+0.j, -0.125+0.j, -0.125+0.j],
#        [ 0.125+0.j,  0.125+0.j, -0.125+0.j, -0.125+0.j, -0.125+0.j,
#         -0.125+0.j,  0.125+0.j,  0.125+0.j],
#        [ 0.125+0.j,  0.125+0.j, -0.125+0.j, -0.125+0.j, -0.125+0.j,
#         -0.125+0.j,  0.125+0.j,  0.125+0.j]]), array([[ 0.125+0.j, -0.125+0.j, -0.125+0.j,  0.125-0.j, -0.125+0.j,
#          0.125-0.j,  0.125+0.j, -0.125+0.j],
#        [-0.125+0.j,  0.125+0.j,  0.125-0.j, -0.125+0.j,  0.125-0.j,
#         -0.125+0.j, -0.125+0.j,  0.125+0.j],
#        [-0.125+0.j,  0.125-0.j,  0.125+0.j, -0.125+0.j,  0.125+0.j,
#         -0.125+0.j, -0.125+0.j,  0.125-0.j],
#        [ 0.125-0.j, -0.125+0.j, -0.125+0.j,  0.125+0.j, -0.125+0.j,
#          0.125+0.j,  0.125-0.j, -0.125+0.j],
#        [-0.125+0.j,  0.125-0.j,  0.125+0.j, -0.125+0.j,  0.125+0.j,
#         -0.125+0.j, -0.125+0.j,  0.125-0.j],
#        [ 0.125-0.j, -0.125+0.j, -0.125+0.j,  0.125+0.j, -0.125+0.j,
#          0.125+0.j,  0.125-0.j, -0.125+0.j],
#        [ 0.125+0.j, -0.125+0.j, -0.125+0.j,  0.125-0.j, -0.125+0.j,
#          0.125-0.j,  0.125+0.j, -0.125+0.j],
#        [-0.125+0.j,  0.125+0.j,  0.125-0.j, -0.125+0.j,  0.125-0.j,
#         -0.125+0.j, -0.125+0.j,  0.125+0.j]])]
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(366)_fitter_data()
#     364             meas_ops = self._measurement_ops(meas_label, measurement)
#     365             block = self._basis_operator_matrix(
# --> 366                 [np.kron(prep_op.T, mop) for mop in meas_ops])
#     367             basis_blocks.append(block)
#     368
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(365)_fitter_data()
#     363             prep_op = self._preparation_op(prep_label, preparation)
#     364             meas_ops = self._measurement_ops(meas_label, measurement)
# --> 365             block = self._basis_operator_matrix(
#     366                 [np.kron(prep_op.T, mop) for mop in meas_ops])
#     367             basis_blocks.append(block)
#
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(367)_fitter_data()
#     365             block = self._basis_operator_matrix(
#     366                 [np.kron(prep_op.T, mop) for mop in meas_ops])
# --> 367             basis_blocks.append(block)
#     368
#     369         return data, np.vstack(basis_blocks), weights
#
# ipdb> n
# > /Users/yangbo/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py(340)_fitter_data()
#     338         else:
#     339             ctkeys = count_keys(len(label))
# --> 340         for label, cts in self._data.items():
#     341
#     342             # Convert counts dict to numpy array
#
# ipdb> np.vstack(basis_blocks)
# array([[ 0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,
#          0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,
#          0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,
#          0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,
#          0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,
#          0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,
#          0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,
#          0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,
#          0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,
#          0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,
#          0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,
#          0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,
#          0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j],
#        [ 0.125-0.j, -0.125-0.j,  0.125-0.j, -0.125-0.j,  0.125-0.j,
#         -0.125-0.j,  0.125-0.j, -0.125-0.j, -0.125-0.j,  0.125-0.j,
#         -0.125-0.j,  0.125-0.j, -0.125-0.j,  0.125-0.j, -0.125-0.j,
#          0.125-0.j,  0.125-0.j, -0.125-0.j,  0.125-0.j, -0.125-0.j,
#          0.125-0.j, -0.125-0.j,  0.125-0.j, -0.125-0.j, -0.125-0.j,
#          0.125-0.j, -0.125-0.j,  0.125-0.j, -0.125-0.j,  0.125-0.j,
#         -0.125-0.j,  0.125-0.j,  0.125-0.j, -0.125-0.j,  0.125-0.j,
#         -0.125-0.j,  0.125-0.j, -0.125-0.j,  0.125-0.j, -0.125-0.j,
#         -0.125-0.j,  0.125-0.j, -0.125-0.j,  0.125-0.j, -0.125-0.j,
#          0.125-0.j, -0.125-0.j,  0.125-0.j,  0.125-0.j, -0.125-0.j,
#          0.125-0.j, -0.125-0.j,  0.125-0.j, -0.125-0.j,  0.125-0.j,
#         -0.125-0.j, -0.125-0.j,  0.125-0.j, -0.125-0.j,  0.125-0.j,
#         -0.125-0.j,  0.125-0.j, -0.125-0.j,  0.125-0.j],
#        [ 0.125-0.j,  0.125-0.j, -0.125-0.j, -0.125-0.j,  0.125-0.j,
#          0.125-0.j, -0.125-0.j, -0.125-0.j,  0.125-0.j,  0.125-0.j,
#         -0.125-0.j, -0.125-0.j,  0.125-0.j,  0.125-0.j, -0.125-0.j,
#         -0.125-0.j, -0.125-0.j, -0.125-0.j,  0.125-0.j,  0.125-0.j,
#         -0.125-0.j, -0.125-0.j,  0.125-0.j,  0.125-0.j, -0.125-0.j,
#         -0.125-0.j,  0.125-0.j,  0.125-0.j, -0.125-0.j, -0.125-0.j,
#          0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j, -0.125-0.j,
#         -0.125-0.j,  0.125-0.j,  0.125-0.j, -0.125-0.j, -0.125-0.j,
#          0.125-0.j,  0.125-0.j, -0.125-0.j, -0.125-0.j,  0.125-0.j,
#          0.125-0.j, -0.125-0.j, -0.125-0.j, -0.125-0.j, -0.125-0.j,
#          0.125-0.j,  0.125-0.j, -0.125-0.j, -0.125-0.j,  0.125-0.j,
#          0.125-0.j, -0.125-0.j, -0.125-0.j,  0.125-0.j,  0.125-0.j,
#         -0.125-0.j, -0.125-0.j,  0.125-0.j,  0.125-0.j],
#        [ 0.125-0.j, -0.125-0.j, -0.125-0.j,  0.125-0.j,  0.125-0.j,
#         -0.125-0.j, -0.125-0.j,  0.125-0.j, -0.125-0.j,  0.125-0.j,
#          0.125-0.j, -0.125-0.j, -0.125-0.j,  0.125-0.j,  0.125-0.j,
#         -0.125-0.j, -0.125-0.j,  0.125-0.j,  0.125-0.j, -0.125-0.j,
#         -0.125-0.j,  0.125-0.j,  0.125-0.j, -0.125-0.j,  0.125-0.j,
#         -0.125-0.j, -0.125-0.j,  0.125-0.j,  0.125-0.j, -0.125-0.j,
#         -0.125-0.j,  0.125-0.j,  0.125-0.j, -0.125-0.j, -0.125-0.j,
#          0.125-0.j,  0.125-0.j, -0.125-0.j, -0.125-0.j,  0.125-0.j,
#         -0.125-0.j,  0.125-0.j,  0.125-0.j, -0.125-0.j, -0.125-0.j,
#          0.125-0.j,  0.125-0.j, -0.125-0.j, -0.125-0.j,  0.125-0.j,
#          0.125-0.j, -0.125-0.j, -0.125-0.j,  0.125-0.j,  0.125-0.j,
#         -0.125-0.j,  0.125-0.j, -0.125-0.j, -0.125-0.j,  0.125-0.j,
#          0.125-0.j, -0.125-0.j, -0.125-0.j,  0.125-0.j],
#        [ 0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j, -0.125-0.j,
#         -0.125-0.j, -0.125-0.j, -0.125-0.j,  0.125-0.j,  0.125-0.j,
#          0.125-0.j,  0.125-0.j, -0.125-0.j, -0.125-0.j, -0.125-0.j,
#         -0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,
#         -0.125-0.j, -0.125-0.j, -0.125-0.j, -0.125-0.j,  0.125-0.j,
#          0.125-0.j,  0.125-0.j,  0.125-0.j, -0.125-0.j, -0.125-0.j,
#         -0.125-0.j, -0.125-0.j, -0.125-0.j, -0.125-0.j, -0.125-0.j,
#         -0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,
#         -0.125-0.j, -0.125-0.j, -0.125-0.j, -0.125-0.j,  0.125-0.j,
#          0.125-0.j,  0.125-0.j,  0.125-0.j, -0.125-0.j, -0.125-0.j,
#         -0.125-0.j, -0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,
#          0.125-0.j, -0.125-0.j, -0.125-0.j, -0.125-0.j, -0.125-0.j,
#          0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j],
#        [ 0.125-0.j, -0.125-0.j,  0.125-0.j, -0.125-0.j, -0.125-0.j,
#          0.125-0.j, -0.125-0.j,  0.125-0.j, -0.125-0.j,  0.125-0.j,
#         -0.125-0.j,  0.125-0.j,  0.125-0.j, -0.125-0.j,  0.125-0.j,
#         -0.125-0.j,  0.125-0.j, -0.125-0.j,  0.125-0.j, -0.125-0.j,
#         -0.125-0.j,  0.125-0.j, -0.125-0.j,  0.125-0.j, -0.125-0.j,
#          0.125-0.j, -0.125-0.j,  0.125-0.j,  0.125-0.j, -0.125-0.j,
#          0.125-0.j, -0.125-0.j, -0.125-0.j,  0.125-0.j, -0.125-0.j,
#          0.125-0.j,  0.125-0.j, -0.125-0.j,  0.125-0.j, -0.125-0.j,
#          0.125-0.j, -0.125-0.j,  0.125-0.j, -0.125-0.j, -0.125-0.j,
#          0.125-0.j, -0.125-0.j,  0.125-0.j, -0.125-0.j,  0.125-0.j,
#         -0.125-0.j,  0.125-0.j,  0.125-0.j, -0.125-0.j,  0.125-0.j,
#         -0.125-0.j,  0.125-0.j, -0.125-0.j,  0.125-0.j, -0.125-0.j,
#         -0.125-0.j,  0.125-0.j, -0.125-0.j,  0.125-0.j],
#        [ 0.125-0.j,  0.125-0.j, -0.125-0.j, -0.125-0.j, -0.125-0.j,
#         -0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,
#         -0.125-0.j, -0.125-0.j, -0.125-0.j, -0.125-0.j,  0.125-0.j,
#          0.125-0.j, -0.125-0.j, -0.125-0.j,  0.125-0.j,  0.125-0.j,
#          0.125-0.j,  0.125-0.j, -0.125-0.j, -0.125-0.j, -0.125-0.j,
#         -0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,
#         -0.125-0.j, -0.125-0.j, -0.125-0.j, -0.125-0.j,  0.125-0.j,
#          0.125-0.j,  0.125-0.j,  0.125-0.j, -0.125-0.j, -0.125-0.j,
#         -0.125-0.j, -0.125-0.j,  0.125-0.j,  0.125-0.j,  0.125-0.j,
#          0.125-0.j, -0.125-0.j, -0.125-0.j,  0.125-0.j,  0.125-0.j,
#         -0.125-0.j, -0.125-0.j, -0.125-0.j, -0.125-0.j,  0.125-0.j,
#          0.125-0.j,  0.125-0.j,  0.125-0.j, -0.125-0.j, -0.125-0.j,
#         -0.125-0.j, -0.125-0.j,  0.125-0.j,  0.125-0.j],
#        [ 0.125-0.j, -0.125-0.j, -0.125-0.j,  0.125-0.j, -0.125-0.j,
#          0.125-0.j,  0.125-0.j, -0.125-0.j, -0.125-0.j,  0.125-0.j,
#          0.125-0.j, -0.125-0.j,  0.125-0.j, -0.125-0.j, -0.125-0.j,
#          0.125-0.j, -0.125-0.j,  0.125-0.j,  0.125-0.j, -0.125-0.j,
#          0.125-0.j, -0.125-0.j, -0.125-0.j,  0.125-0.j,  0.125-0.j,
#         -0.125-0.j, -0.125-0.j,  0.125-0.j, -0.125-0.j,  0.125-0.j,
#          0.125-0.j, -0.125-0.j, -0.125-0.j,  0.125-0.j,  0.125-0.j,
#         -0.125-0.j,  0.125-0.j, -0.125-0.j, -0.125-0.j,  0.125-0.j,
#          0.125-0.j, -0.125-0.j, -0.125-0.j,  0.125-0.j, -0.125-0.j,
#          0.125-0.j,  0.125-0.j, -0.125-0.j,  0.125-0.j, -0.125-0.j,
#         -0.125-0.j,  0.125-0.j, -0.125-0.j,  0.125-0.j,  0.125-0.j,
#         -0.125-0.j, -0.125-0.j,  0.125-0.j,  0.125-0.j, -0.125-0.j,
#          0.125-0.j, -0.125-0.j, -0.125-0.j,  0.125-0.j]])
# ipdb> q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# /var/folders/vr/d82vcp297v78vk4sb0_nzzdc0000gn/T/ipykernel_28784/2411698869.py in <module>
#       1 from IPython.core.debugger import Pdb; Pdb().set_trace()
# ----> 2 data, basis_matrix, weights = stf._fitter_data(True, 0.5)
#
# ~/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py in _fitter_data(self, standard_weights, beta)
#     338         else:
#     339             ctkeys = count_keys(len(label))
# --> 340         for label, cts in self._data.items():
#     341
#     342             # Convert counts dict to numpy array
#
# ~/opt/anaconda3/envs/qiskitenv/lib/python3.9/site-packages/qiskit/ignis/verification/tomography/fitters/base_fitter.py in _fitter_data(self, standard_weights, beta)
#     338         else:
#     339             ctkeys = count_keys(len(label))
# --> 340         for label, cts in self._data.items():
#     341
#     342             # Convert counts dict to numpy array
#
# ~/opt/anaconda3/envs/qiskitenv/lib/python3.9/bdb.py in trace_dispatch(self, frame, event, arg)
#      86             return # None
#      87         if event == 'line':
# ---> 88             return self.dispatch_line(frame)
#      89         if event == 'call':
#      90             return self.dispatch_call(frame, arg)
#
# ~/opt/anaconda3/envs/qiskitenv/lib/python3.9/bdb.py in dispatch_line(self, frame)
#     111         if self.stop_here(frame) or self.break_here(frame):
#     112             self.user_line(frame)
# --> 113             if self.quitting: raise BdbQuit
#     114         return self.trace_dispatch
#     115
#
# BdbQuit:

# %%
next(iter(stf._data))
# Out:
# ('X', 'X', 'X')

# %%
# Compute the state tomography based on the st_qcs quantum circuits and the results from those ciricuits
def state_tomo(result, st_qcs):
    # The expected final state; necessary to determine state tomography fidelity
    target_state = (One^One^Zero).to_matrix()  # DO NOT MODIFY (|q_5,q_3,q_1> = |110>)
    # Fit state tomography results
    tomo_fitter = StateTomographyFitter(result, st_qcs)
    rho_fit = tomo_fitter.fit(method='lstsq')
    # Compute fidelity
    fid = state_fidelity(rho_fit, target_state)
    return fid

# %%
# Compute tomography fidelities for each repetition
fids = []
for job in jobs:
    fid = state_tomo(job.result(), st_qcs)
    fids.append(fid)
    
print('state tomography fidelity = {:.4f} \u00B1 {:.4f}'.format(np.mean(fids), np.std(fids)))
# Out:
# state tomography fidelity = 0.8305 ± 0.0023
